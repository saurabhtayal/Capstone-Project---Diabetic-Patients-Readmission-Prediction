# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.metrics import roc_curve, precision_recall_curve, classification_report, confusion_matrix
from sklearn.metrics import recall_score, precision_score, f1_score, accuracy_score, roc_auc_score
from sklearn.ensemble import RandomForestClassifier
from imblearn.under_sampling import RandomUnderSampler, TomekLinks
from imblearn.over_sampling import SMOTE, SMOTENC, RandomOverSampler
from imblearn.combine import SMOTETomek
from scipy.stats import randint, uniform
import matplotlib.pyplot as plt
import seaborn as sns
import time
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/My Drive/PGPDSE/Capstone/CSV Files/Diabetes_Preprocessed_Before_Feature_Selection.csv')
df.head()
# Out:
#               race  gender  age discharge_disposition_id admission_source_id  \
# 0        Caucasian       0    5            Not Available            Referral
# 1        Caucasian       0   15       Discharged to home           Emergency
# 2  AfricanAmerican       0   25       Discharged to home           Emergency
# 3        Caucasian       1   35       Discharged to home           Emergency
# 4        Caucasian       1   45       Discharged to home           Emergency
#
#    time_in_hospital  num_lab_procedures  num_procedures  num_medications  \
# 0                 1                  41               0                1
# 1                 3                  59               0               18
# 2                 2                  11               5               13
# 3                 2                  44               1               16
# 4                 1                  51               0                8
#
#                                         diag_1        diag_2  \
# 0                                     Diabetes  Not Required
# 1  Endocrine, Nutritional, Metabolic, Immunity      Diabetes
# 2                        Pregnancy, Childbirth      Diabetes
# 3                     Infectious and Parasitic      Diabetes
# 4                                    Neoplasms     Neoplasms
#
#                                         diag_3  number_diagnoses  \
# 0                                 Not Required                 1
# 1  Endocrine, Nutritional, Metabolic, Immunity                 9
# 2                    External causes of injury                 6
# 3                                  Circulatory                 7
# 4                                     Diabetes                 5
#
#   max_glu_serum A1Cresult  metformin  repaglinide  glimepiride  glipizide  \
# 0          None      None         -2           -2           -2         -2
# 1          None      None         -2           -2           -2         -2
# 2          None      None         -2           -2           -2          0
# 3          None      None         -2           -2           -2         -2
# 4          None      None         -2           -2           -2          0
#
#    glyburide  pioglitazone  rosiglitazone  insulin  diabetesMed  readmitted  \
# 0         -2            -2             -2       -2            0           0
# 1         -2            -2             -2        1            1           0
# 2         -2            -2             -2       -2            1           0
# 3         -2            -2             -2        1            1           0
# 4         -2            -2             -2        0            1           0
#
#    preceding_year_visits  number_changes insulin_treatment
# 0                      0               0            no_med
# 1                      0               1      insulin_only
# 2                      3               0        other_meds
# 3                      0               1      insulin_only
# 4                      0               0     insulin_combo

# %%
df.shape
# Out:
# (97070, 28)

# %%
X = df.drop('readmitted', 1)
y = df['readmitted']
X_dum = pd.get_dummies(X, drop_first = True)
X_train, X_test, y_train, y_test = train_test_split(X_dum, y, test_size = 0.3, random_state = 0, stratify = y)

# %%
model = RandomForestClassifier(random_state = 0, n_jobs = -1)
model.fit(X_train, y_train)
sorted(zip(model.feature_importances_, X_train.columns), reverse = True)
# Out:
# [(0.09878159999880749, 'num_lab_procedures'),
#  (0.08720190393977335, 'num_medications'),
#  (0.06318743211903118, 'time_in_hospital'),
#  (0.05554712572719704, 'preceding_year_visits'),
#  (0.05145485596828784, 'age'),
#  (0.04438641347711193, 'num_procedures'),
#  (0.03973634017483778, 'number_diagnoses'),
#  (0.022522569138021604, 'gender'),
#  (0.02090317188290997, 'insulin'),
#  (0.017551457662588057, 'admission_source_id_Referral'),
#  (0.01702549936800917, 'race_Caucasian'),
#  (0.016753609539938923, 'diag_2_Circulatory'),
#  (0.016741771574289275, 'diag_3_Circulatory'),
#  (0.015543278385913326, 'diag_1_Circulatory'),
#  (0.012561560461283984, 'diag_3_Diabetes'),
#  (0.012350080565701596, 'number_changes'),
#  (0.012299510396421817, 'metformin'),
#  (0.012045603077577184,
#   'discharge_disposition_id_Transferred to another medical facility'),
#  (0.011635478446431223, 'glipizide'),
#  (0.010516778044156827, 'glyburide'),
#  (0.010163062655697398, 'diag_2_Diabetes'),
#  (0.01010559628942244, 'diag_2_Respiratory'),
#  (0.0100883775696952,
#   'discharge_disposition_id_Discharged to home with home health service'),
#  (0.009861205336143118, 'diag_1_Respiratory'),
#  (0.009541735854246872, 'A1Cresult_None'),
#  (0.009456521557055696, 'diag_2_Genitourinary'),
#  (0.009269843283046919, 'diag_1_Digestive'),
#  (0.009250134233613927, 'diag_3_Endocrine, Nutritional, Metabolic, Immunity'),
#  (0.009187373456018093, 'diag_2_Endocrine, Nutritional, Metabolic, Immunity'),
#  (0.00914375385241023, 'diag_3_Respiratory'),
#  (0.008412085382386815, 'diag_3_Genitourinary'),
#  (0.008196684713383518, 'insulin_treatment_insulin_only'),
#  (0.007959360168328088, 'pioglitazone'),
#  (0.007862638614371323, 'insulin_treatment_other_meds'),
#  (0.00781870785114297, 'diag_1_Injury and Poisoning'),
#  (0.0076940614423353865, 'diag_1_Diabetes'),
#  (0.006955954048879901, 'rosiglitazone'),
#  (0.006625202355814756, 'diag_1_Genitourinary'),
#  (0.006575065732355813, 'glimepiride'),
#  (0.006456942303197066,
#   'admission_source_id_Transferred from another health care facility'),
#  (0.006427770753923742, 'diag_3_External causes of injury'),
#  (0.0062477921118006445, 'A1Cresult_>8'),
#  (0.0062317053688556775, 'diag_3_Digestive'),
#  (0.005979123214141786, 'discharge_disposition_id_Not Available'),
#  (0.005973934274125307, 'diag_2_Digestive'),
#  (0.0058368628107966815, 'admission_source_id_Not Available'),
#  (0.005492522036596821, 'diag_2_Skin and Subcutaneous Tissue'),
#  (0.005093242778375095, 'diag_1_Musculoskeletal System and Connective Tissue'),
#  (0.0050710960917026305, 'max_glu_serum_None'),
#  (0.005003618759890448, 'diag_1_Endocrine, Nutritional, Metabolic, Immunity'),
#  (0.004974829814121398, 'A1Cresult_Norm'),
#  (0.004863592694204364, 'diag_3_Skin and Subcutaneous Tissue'),
#  (0.004690587352074829, 'diag_3_Mental Disorders'),
#  (0.004633371059915228, 'insulin_treatment_no_med'),
#  (0.004630975414135854, 'diabetesMed'),
#  (0.004628495571957282, 'diag_3_Other Symptoms'),
#  (0.004589539436348075, 'diag_2_External causes of injury'),
#  (0.004407262704695706, 'diag_1_Infectious and Parasitic'),
#  (0.004374017591111988, 'diag_1_Neoplasms'),
#  (0.0041972533937578455, 'diag_2_Injury and Poisoning'),
#  (0.004196016286270534, 'diag_2_Neoplasms'),
#  (0.004114061341357537, 'diag_2_Other Symptoms'),
#  (0.0040195539070640345, 'diag_1_Skin and Subcutaneous Tissue'),
#  (0.0037980869947465854, 'diag_1_Other Symptoms'),
#  (0.003789033675845071, 'diag_3_Musculoskeletal System and Connective Tissue'),
#  (0.00377884755477171, 'diag_2_Mental Disorders'),
#  (0.0037315002769762644, 'diag_2_Infectious and Parasitic'),
#  (0.0036655565528327036, 'diag_3_Injury and Poisoning'),
#  (0.003647974493676677, 'diag_3_Infectious and Parasitic'),
#  (0.00361990941147355, 'repaglinide'),
#  (0.0036159474787554003, 'diag_3_Neoplasms'),
#  (0.0035621963086632973, 'diag_1_Mental Disorders'),
#  (0.0035020523739668656, 'diag_1_External causes of injury'),
#  (0.0033755079483402204, 'diag_3_Nervous'),
#  (0.0033092947270207977, 'race_Hispanic'),
#  (0.003225558618887144, 'max_glu_serum_Norm'),
#  (0.003031272592870494, 'diag_2_Musculoskeletal System and Connective Tissue'),
#  (0.0028560835879363686, 'diag_2_Nervous'),
#  (0.0028326748493079624, 'race_Other'),
#  (0.002440230865759726, 'max_glu_serum_>300'),
#  (0.002353422077442724, 'diag_1_Nervous'),
#  (0.0021266549292304564, 'discharge_disposition_id_Left AMA'),
#  (0.002075893639572351, 'diag_1_Congenital Anomalies'),
#  (0.0017633052408857607, 'diag_3_Congenital Anomalies'),
#  (0.001546910527415495, 'diag_2_Congenital Anomalies'),
#  (0.0015091468379409018, 'race_Asian'),
#  (0.0013291380900846525,
#   'discharge_disposition_id_Still patient/referred to this institution'),
#  (0.0011660435618419964, 'diag_3_Not Required'),
#  (0.0007593152679839399, 'diag_2_Not Required'),
#  (0.0007504087504773617, 'diag_3_Sense Organs'),
#  (0.0006302573911000943, 'diag_1_Pregnancy, Childbirth'),
#  (0.0003355683141457532, 'diag_2_Pregnancy, Childbirth'),
#  (0.00031764821168512697, 'diag_1_Sense Organs'),
#  (0.00030606436203423174, 'diag_2_Sense Organs'),
#  (0.0002009230712694598, 'diag_3_Pregnancy, Childbirth')]

# %%
model_cw1 = RandomForestClassifier(random_state = 0, n_jobs = -1, class_weight = 'balanced')
model_cw1.fit(X_train, y_train)
sorted(zip(model_cw1.feature_importances_, X_train.columns), reverse = True)
# Out:
# [(0.09722876488991944, 'num_lab_procedures'),
#  (0.08517285276620576, 'num_medications'),
#  (0.062411255902758415, 'time_in_hospital'),
#  (0.06111154118857542, 'preceding_year_visits'),
#  (0.05103688212488469, 'age'),
#  (0.04399676244160737, 'num_procedures'),
#  (0.042068541788467646, 'number_diagnoses'),
#  (0.02081980606729452, 'gender'),
#  (0.020719372659299306, 'insulin'),
#  (0.017292437898349142,
#   'discharge_disposition_id_Transferred to another medical facility'),
#  (0.017149048558068244, 'admission_source_id_Referral'),
#  (0.016908302300800246, 'diag_3_Circulatory'),
#  (0.016702707688939996, 'race_Caucasian'),
#  (0.016596775493678294, 'diag_2_Circulatory'),
#  (0.015091184322786404, 'diag_1_Circulatory'),
#  (0.01272820745092543, 'diag_3_Diabetes'),
#  (0.012615762984400113, 'metformin'),
#  (0.012368744244885727, 'number_changes'),
#  (0.011584394380125533, 'glipizide'),
#  (0.010820693664102368,
#   'discharge_disposition_id_Discharged to home with home health service'),
#  (0.010622844091598032, 'diag_2_Respiratory'),
#  (0.01053756446197475, 'diag_1_Respiratory'),
#  (0.01037461110551242, 'A1Cresult_None'),
#  (0.010351877750659409, 'diag_2_Diabetes'),
#  (0.010178280667064861, 'glyburide'),
#  (0.009994835382705626, 'diag_3_Endocrine, Nutritional, Metabolic, Immunity'),
#  (0.009553877655705742, 'diag_2_Genitourinary'),
#  (0.009408006175287965, 'diag_1_Digestive'),
#  (0.009279010753414477, 'diag_2_Endocrine, Nutritional, Metabolic, Immunity'),
#  (0.009177257611910164, 'diag_3_Respiratory'),
#  (0.00879275243608408, 'insulin_treatment_insulin_only'),
#  (0.008183269101647994, 'diag_3_Genitourinary'),
#  (0.008017649976653442, 'pioglitazone'),
#  (0.007941884662425696, 'insulin_treatment_other_meds'),
#  (0.007629388557041312, 'diag_1_Diabetes'),
#  (0.007628662952101425, 'diag_1_Injury and Poisoning'),
#  (0.007187624990336452, 'rosiglitazone'),
#  (0.00700894712305899, 'diag_1_Genitourinary'),
#  (0.006839955759154149, 'diag_3_External causes of injury'),
#  (0.006785847581978152,
#   'admission_source_id_Transferred from another health care facility'),
#  (0.0064716187857834, 'glimepiride'),
#  (0.006286860064526407, 'A1Cresult_>8'),
#  (0.006118340093739085, 'diag_3_Digestive'),
#  (0.0060457360352991416, 'discharge_disposition_id_Not Available'),
#  (0.006036178794445437, 'admission_source_id_Not Available'),
#  (0.005768502965285327, 'diag_2_Digestive'),
#  (0.0054189310998398015, 'A1Cresult_Norm'),
#  (0.00537072003549743, 'diag_2_Skin and Subcutaneous Tissue'),
#  (0.005337814171615458, 'diag_1_Musculoskeletal System and Connective Tissue'),
#  (0.005043396086326165, 'insulin_treatment_no_med'),
#  (0.004940155697254297, 'max_glu_serum_None'),
#  (0.004904805369093912, 'diabetesMed'),
#  (0.004665990495010878, 'diag_1_Endocrine, Nutritional, Metabolic, Immunity'),
#  (0.004645882564133822, 'diag_3_Mental Disorders'),
#  (0.004405590047542983, 'diag_3_Skin and Subcutaneous Tissue'),
#  (0.004372813072962198, 'diag_3_Other Symptoms'),
#  (0.004321986941853035, 'diag_1_Infectious and Parasitic'),
#  (0.004250727191801496, 'diag_1_Neoplasms'),
#  (0.004233588665479884, 'diag_2_External causes of injury'),
#  (0.0041109567172601695, 'diag_2_Other Symptoms'),
#  (0.003978092549278533, 'diag_2_Neoplasms'),
#  (0.003961850400741704, 'diag_1_Skin and Subcutaneous Tissue'),
#  (0.003877163076634806, 'diag_2_Injury and Poisoning'),
#  (0.0038172762139016907, 'diag_2_Mental Disorders'),
#  (0.003743773259503321, 'diag_1_Other Symptoms'),
#  (0.003549560950346789, 'diag_2_Infectious and Parasitic'),
#  (0.0034029049681409047,
#   'diag_3_Musculoskeletal System and Connective Tissue'),
#  (0.003247946202404246, 'diag_1_Mental Disorders'),
#  (0.003238624943864349, 'diag_3_Injury and Poisoning'),
#  (0.003233723489168164, 'diag_3_Infectious and Parasitic'),
#  (0.0031587924051024933, 'max_glu_serum_Norm'),
#  (0.003012717771726943, 'diag_3_Neoplasms'),
#  (0.003007191092996561, 'race_Hispanic'),
#  (0.0029927033972501614, 'diag_3_Nervous'),
#  (0.0029387892090028326, 'repaglinide'),
#  (0.002825415544770988, 'diag_2_Musculoskeletal System and Connective Tissue'),
#  (0.0027371760708324194, 'diag_1_External causes of injury'),
#  (0.0024096192626679573, 'race_Other'),
#  (0.0021466230253950696, 'diag_2_Nervous'),
#  (0.0019244890705821338, 'diag_1_Nervous'),
#  (0.0018501285039032637, 'max_glu_serum_>300'),
#  (0.0017650551251901215, 'diag_1_Congenital Anomalies'),
#  (0.0015804689316767846, 'discharge_disposition_id_Left AMA'),
#  (0.0012288785495681253, 'diag_3_Congenital Anomalies'),
#  (0.0012105403640932958, 'diag_3_Not Required'),
#  (0.0011060137229622383, 'diag_1_Pregnancy, Childbirth'),
#  (0.0011021540299728909, 'diag_2_Congenital Anomalies'),
#  (0.0010767614893731736, 'race_Asian'),
#  (0.0007983306057245989,
#   'discharge_disposition_id_Still patient/referred to this institution'),
#  (0.0005388819762843593, 'diag_2_Pregnancy, Childbirth'),
#  (0.0004727173720422314, 'diag_3_Sense Organs'),
#  (0.00041760954788145705, 'diag_2_Not Required'),
#  (0.0004106765367726597, 'diag_1_Sense Organs'),
#  (0.0003579144839645744, 'diag_3_Pregnancy, Childbirth'),
#  (0.00021065334913856625, 'diag_2_Sense Organs')]

# %%
model_cw2 = RandomForestClassifier(random_state = 0, n_jobs = -1, class_weight = 'balanced_subsample')
model_cw2.fit(X_train, y_train)
sorted(zip(model_cw2.feature_importances_, X_train.columns), reverse = True)
# Out:
# [(0.09671993472854003, 'num_lab_procedures'),
#  (0.08548228657373078, 'num_medications'),
#  (0.062446399779969713, 'time_in_hospital'),
#  (0.06042540819753317, 'preceding_year_visits'),
#  (0.05120547544362624, 'age'),
#  (0.04415096538210633, 'num_procedures'),
#  (0.041227826263442145, 'number_diagnoses'),
#  (0.020495090825902097, 'gender'),
#  (0.0201503462093601, 'insulin'),
#  (0.017333868624548127,
#   'discharge_disposition_id_Transferred to another medical facility'),
#  (0.016921752064277085, 'diag_3_Circulatory'),
#  (0.01687463532578772, 'admission_source_id_Referral'),
#  (0.01661287811728064, 'diag_2_Circulatory'),
#  (0.016412853715092886, 'race_Caucasian'),
#  (0.015584348159338826, 'diag_1_Circulatory'),
#  (0.012845175947945077, 'diag_3_Diabetes'),
#  (0.012753774968281301, 'metformin'),
#  (0.012294583089840683, 'number_changes'),
#  (0.0117224876851911, 'glipizide'),
#  (0.010831088323488567, 'diag_1_Respiratory'),
#  (0.010619770473868244, 'diag_2_Respiratory'),
#  (0.010508531378868785, 'diag_2_Diabetes'),
#  (0.010318352671728636,
#   'discharge_disposition_id_Discharged to home with home health service'),
#  (0.0102403660769333, 'glyburide'),
#  (0.010236738383915403, 'A1Cresult_None'),
#  (0.00965942067282325, 'diag_2_Genitourinary'),
#  (0.00956445983967468, 'diag_3_Endocrine, Nutritional, Metabolic, Immunity'),
#  (0.009531182211338144, 'diag_1_Digestive'),
#  (0.009377275501454178, 'diag_3_Respiratory'),
#  (0.009152055685245911, 'diag_2_Endocrine, Nutritional, Metabolic, Immunity'),
#  (0.008728756412683348, 'insulin_treatment_insulin_only'),
#  (0.008179404661938817, 'diag_3_Genitourinary'),
#  (0.008034838697172138, 'pioglitazone'),
#  (0.008019089860555061, 'insulin_treatment_other_meds'),
#  (0.007885996531280491, 'diag_1_Injury and Poisoning'),
#  (0.00763690101286623, 'diag_1_Diabetes'),
#  (0.007255550421452613, 'rosiglitazone'),
#  (0.007080865195709952, 'diag_1_Genitourinary'),
#  (0.0069706585155562715,
#   'admission_source_id_Transferred from another health care facility'),
#  (0.006851931653787957, 'diag_3_External causes of injury'),
#  (0.006629028068392423, 'glimepiride'),
#  (0.0061798178861659355, 'A1Cresult_>8'),
#  (0.006088543367046587, 'admission_source_id_Not Available'),
#  (0.00596642664653767, 'diag_3_Digestive'),
#  (0.005909060552252494, 'discharge_disposition_id_Not Available'),
#  (0.005771594674414166, 'diag_2_Digestive'),
#  (0.0054913398154374125,
#   'diag_1_Musculoskeletal System and Connective Tissue'),
#  (0.005326436208016412, 'diag_2_Skin and Subcutaneous Tissue'),
#  (0.005210966432270522, 'A1Cresult_Norm'),
#  (0.005121193342692426, 'diabetesMed'),
#  (0.005087853966856566, 'insulin_treatment_no_med'),
#  (0.005011156244625077, 'max_glu_serum_None'),
#  (0.004763681684704581, 'diag_1_Endocrine, Nutritional, Metabolic, Immunity'),
#  (0.004669145780622701, 'diag_3_Mental Disorders'),
#  (0.004378876115759202, 'diag_1_Neoplasms'),
#  (0.004360088535280981, 'diag_3_Skin and Subcutaneous Tissue'),
#  (0.004358252831311144, 'diag_1_Infectious and Parasitic'),
#  (0.0043261789828598326, 'diag_3_Other Symptoms'),
#  (0.004296771194195075, 'diag_2_External causes of injury'),
#  (0.004135701329011641, 'diag_1_Skin and Subcutaneous Tissue'),
#  (0.004103995158530644, 'diag_2_Neoplasms'),
#  (0.0040399017890326155, 'diag_2_Other Symptoms'),
#  (0.003907948139467887, 'diag_1_Other Symptoms'),
#  (0.0038946228137219712, 'diag_2_Injury and Poisoning'),
#  (0.003777407293286838, 'diag_2_Mental Disorders'),
#  (0.003510943601115287, 'diag_2_Infectious and Parasitic'),
#  (0.003389124370918575, 'diag_3_Injury and Poisoning'),
#  (0.00333481323549515, 'diag_3_Infectious and Parasitic'),
#  (0.003273026066736825, 'diag_3_Musculoskeletal System and Connective Tissue'),
#  (0.0032443172210207486, 'diag_1_Mental Disorders'),
#  (0.003193316364169054, 'max_glu_serum_Norm'),
#  (0.0031515248618632077, 'repaglinide'),
#  (0.0031194160462229906, 'diag_3_Neoplasms'),
#  (0.003075901466642656, 'race_Hispanic'),
#  (0.002951951054364291, 'diag_3_Nervous'),
#  (0.0028485885622095367, 'diag_1_External causes of injury'),
#  (0.0028243429724541264,
#   'diag_2_Musculoskeletal System and Connective Tissue'),
#  (0.0024200125207718324, 'race_Other'),
#  (0.0022726939742504387, 'diag_2_Nervous'),
#  (0.0019330067303148634, 'diag_1_Nervous'),
#  (0.0018419965065323575, 'max_glu_serum_>300'),
#  (0.0018232764267294113, 'diag_1_Congenital Anomalies'),
#  (0.0016038299179987716, 'discharge_disposition_id_Left AMA'),
#  (0.001316520591660964, 'diag_3_Congenital Anomalies'),
#  (0.0011874767637631433, 'diag_3_Not Required'),
#  (0.001147188160844072, 'diag_2_Congenital Anomalies'),
#  (0.0011314334883975074, 'race_Asian'),
#  (0.0009900057510128324, 'diag_1_Pregnancy, Childbirth'),
#  (0.0008001826425237049,
#   'discharge_disposition_id_Still patient/referred to this institution'),
#  (0.0005656497138020462, 'diag_2_Pregnancy, Childbirth'),
#  (0.0005039043395985483, 'diag_3_Sense Organs'),
#  (0.000425308743261679, 'diag_2_Not Required'),
#  (0.00041349205356368827, 'diag_1_Sense Organs'),
#  (0.00034749666612075207, 'diag_3_Pregnancy, Childbirth'),
#  (0.0002099450490122715, 'diag_2_Sense Organs')]

# %%
fi_df = pd.DataFrame({'Features' : X_train.columns, 'No_Class_Weight' : model.feature_importances_,
                          'Balanced' : model_cw1.feature_importances_, 'Balanced_Subsample' : model_cw2.feature_importances_})
fi_df
# Out:
#                                              Features  No_Class_Weight  \
# 0                                              gender         0.022523
# 1                                                 age         0.051455
# 2                                    time_in_hospital         0.063187
# 3                                  num_lab_procedures         0.098782
# 4                                      num_procedures         0.044386
# 5                                     num_medications         0.087202
# 6                                    number_diagnoses         0.039736
# 7                                           metformin         0.012300
# 8                                         repaglinide         0.003620
# 9                                         glimepiride         0.006575
# 10                                          glipizide         0.011635
# 11                                          glyburide         0.010517
# 12                                       pioglitazone         0.007959
# 13                                      rosiglitazone         0.006956
# 14                                            insulin         0.020903
# 15                                        diabetesMed         0.004631
# 16                              preceding_year_visits         0.055547
# 17                                     number_changes         0.012350
# 18                                         race_Asian         0.001509
# 19                                     race_Caucasian         0.017025
# 20                                      race_Hispanic         0.003309
# 21                                         race_Other         0.002833
# 22  discharge_disposition_id_Discharged to home wi...         0.010088
# 23                  discharge_disposition_id_Left AMA         0.002127
# 24             discharge_disposition_id_Not Available         0.005979
# 25  discharge_disposition_id_Still patient/referre...         0.001329
# 26  discharge_disposition_id_Transferred to anothe...         0.012046
# 27                  admission_source_id_Not Available         0.005837
# 28                       admission_source_id_Referral         0.017551
# 29  admission_source_id_Transferred from another h...         0.006457
# 30                                 diag_1_Circulatory         0.015543
# 31                        diag_1_Congenital Anomalies         0.002076
# 32                                    diag_1_Diabetes         0.007694
# 33                                   diag_1_Digestive         0.009270
# 34  diag_1_Endocrine, Nutritional, Metabolic, Immu...         0.005004
# 35                   diag_1_External causes of injury         0.003502
# 36                               diag_1_Genitourinary         0.006625
# 37                    diag_1_Infectious and Parasitic         0.004407
# 38                        diag_1_Injury and Poisoning         0.007819
# 39                            diag_1_Mental Disorders         0.003562
# 40  diag_1_Musculoskeletal System and Connective T...         0.005093
# 41                                   diag_1_Neoplasms         0.004374
# 42                                     diag_1_Nervous         0.002353
# 43                              diag_1_Other Symptoms         0.003798
# 44                       diag_1_Pregnancy, Childbirth         0.000630
# 45                                 diag_1_Respiratory         0.009861
# 46                                diag_1_Sense Organs         0.000318
# 47                diag_1_Skin and Subcutaneous Tissue         0.004020
# 48                                 diag_2_Circulatory         0.016754
# 49                        diag_2_Congenital Anomalies         0.001547
# 50                                    diag_2_Diabetes         0.010163
# 51                                   diag_2_Digestive         0.005974
# 52  diag_2_Endocrine, Nutritional, Metabolic, Immu...         0.009187
# 53                   diag_2_External causes of injury         0.004590
# 54                               diag_2_Genitourinary         0.009457
# 55                    diag_2_Infectious and Parasitic         0.003732
# 56                        diag_2_Injury and Poisoning         0.004197
# 57                            diag_2_Mental Disorders         0.003779
# 58  diag_2_Musculoskeletal System and Connective T...         0.003031
# 59                                   diag_2_Neoplasms         0.004196
# 60                                     diag_2_Nervous         0.002856
# 61                                diag_2_Not Required         0.000759
# 62                              diag_2_Other Symptoms         0.004114
# 63                       diag_2_Pregnancy, Childbirth         0.000336
# 64                                 diag_2_Respiratory         0.010106
# 65                                diag_2_Sense Organs         0.000306
# 66                diag_2_Skin and Subcutaneous Tissue         0.005493
# 67                                 diag_3_Circulatory         0.016742
# 68                        diag_3_Congenital Anomalies         0.001763
# 69                                    diag_3_Diabetes         0.012562
# 70                                   diag_3_Digestive         0.006232
# 71  diag_3_Endocrine, Nutritional, Metabolic, Immu...         0.009250
# 72                   diag_3_External causes of injury         0.006428
# 73                               diag_3_Genitourinary         0.008412
# 74                    diag_3_Infectious and Parasitic         0.003648
# 75                        diag_3_Injury and Poisoning         0.003666
# 76                            diag_3_Mental Disorders         0.004691
# 77  diag_3_Musculoskeletal System and Connective T...         0.003789
# 78                                   diag_3_Neoplasms         0.003616
# 79                                     diag_3_Nervous         0.003376
# 80                                diag_3_Not Required         0.001166
# 81                              diag_3_Other Symptoms         0.004628
# 82                       diag_3_Pregnancy, Childbirth         0.000201
# 83                                 diag_3_Respiratory         0.009144
# 84                                diag_3_Sense Organs         0.000750
# 85                diag_3_Skin and Subcutaneous Tissue         0.004864
# 86                                 max_glu_serum_>300         0.002440
# 87                                 max_glu_serum_None         0.005071
# 88                                 max_glu_serum_Norm         0.003226
# 89                                       A1Cresult_>8         0.006248
# 90                                     A1Cresult_None         0.009542
# 91                                     A1Cresult_Norm         0.004975
# 92                     insulin_treatment_insulin_only         0.008197
# 93                           insulin_treatment_no_med         0.004633
# 94                       insulin_treatment_other_meds         0.007863
#
#     Balanced  Balanced_Subsample
# 0   0.020820            0.020495
# 1   0.051037            0.051205
# 2   0.062411            0.062446
# 3   0.097229            0.096720
# 4   0.043997            0.044151
# 5   0.085173            0.085482
# 6   0.042069            0.041228
# 7   0.012616            0.012754
# 8   0.002939            0.003152
# 9   0.006472            0.006629
# 10  0.011584            0.011722
# 11  0.010178            0.010240
# 12  0.008018            0.008035
# 13  0.007188            0.007256
# 14  0.020719            0.020150
# 15  0.004905            0.005121
# 16  0.061112            0.060425
# 17  0.012369            0.012295
# 18  0.001077            0.001131
# 19  0.016703            0.016413
# 20  0.003007            0.003076
# 21  0.002410            0.002420
# 22  0.010821            0.010318
# 23  0.001580            0.001604
# 24  0.006046            0.005909
# 25  0.000798            0.000800
# 26  0.017292            0.017334
# 27  0.006036            0.006089
# 28  0.017149            0.016875
# 29  0.006786            0.006971
# 30  0.015091            0.015584
# 31  0.001765            0.001823
# 32  0.007629            0.007637
# 33  0.009408            0.009531
# 34  0.004666            0.004764
# 35  0.002737            0.002849
# 36  0.007009            0.007081
# 37  0.004322            0.004358
# 38  0.007629            0.007886
# 39  0.003248            0.003244
# 40  0.005338            0.005491
# 41  0.004251            0.004379
# 42  0.001924            0.001933
# 43  0.003744            0.003908
# 44  0.001106            0.000990
# 45  0.010538            0.010831
# 46  0.000411            0.000413
# 47  0.003962            0.004136
# 48  0.016597            0.016613
# 49  0.001102            0.001147
# 50  0.010352            0.010509
# 51  0.005769            0.005772
# 52  0.009279            0.009152
# 53  0.004234            0.004297
# 54  0.009554            0.009659
# 55  0.003550            0.003511
# 56  0.003877            0.003895
# 57  0.003817            0.003777
# 58  0.002825            0.002824
# 59  0.003978            0.004104
# 60  0.002147            0.002273
# 61  0.000418            0.000425
# 62  0.004111            0.004040
# 63  0.000539            0.000566
# 64  0.010623            0.010620
# 65  0.000211            0.000210
# 66  0.005371            0.005326
# 67  0.016908            0.016922
# 68  0.001229            0.001317
# 69  0.012728            0.012845
# 70  0.006118            0.005966
# 71  0.009995            0.009564
# 72  0.006840            0.006852
# 73  0.008183            0.008179
# 74  0.003234            0.003335
# 75  0.003239            0.003389
# 76  0.004646            0.004669
# 77  0.003403            0.003273
# 78  0.003013            0.003119
# 79  0.002993            0.002952
# 80  0.001211            0.001187
# 81  0.004373            0.004326
# 82  0.000358            0.000347
# 83  0.009177            0.009377
# 84  0.000473            0.000504
# 85  0.004406            0.004360
# 86  0.001850            0.001842
# 87  0.004940            0.005011
# 88  0.003159            0.003193
# 89  0.006287            0.006180
# 90  0.010375            0.010237
# 91  0.005419            0.005211
# 92  0.008793            0.008729
# 93  0.005043            0.005088
# 94  0.007942            0.008019

# %% [markdown]
# ### Without Class Weight

# %%
imp = fi_df[fi_df['No_Class_Weight'] >= 0]['Features']
print("Number of features:", len(imp))
model = RandomForestClassifier(n_jobs = -1, random_state = 0)
start_time = time.time()
model.fit(X_train[imp], y_train)
end_time = time.time()
print("Training Time:", end_time - start_time)
y_train_pred = model.predict(X_train[imp])
y_train_prob = model.predict_proba(X_train[imp])[:, 1]
start_time = time.time()
y_test_pred = model.predict(X_test[imp])
end_time = time.time()
print("Prediction Time:", end_time - start_time)
y_test_prob = model.predict_proba(X_test[imp])[:, 1]
print("Train Accuracy Score:", accuracy_score(y_train, y_train_pred))
print("Train Confusion Matrix:\n", confusion_matrix(y_train, y_train_pred), '\n')
print("Train F1 Score:", f1_score(y_train, y_train_pred))
print("Train Precision Score:", precision_score(y_train, y_train_pred))
print("Train Recall Score:", recall_score(y_train, y_train_pred))
print("Train ROC_AUC Score:", roc_auc_score(y_train, y_train_prob))
print()
print("Test Accuracy Score:", accuracy_score(y_test, y_test_pred))
print("Test Confusion Matrix:\n", confusion_matrix(y_test, y_test_pred), '\n')
print("Test F1 Score:", f1_score(y_test, y_test_pred))
print("Test Precision Score:", precision_score(y_test, y_test_pred))
print("Test Recall Score:", recall_score(y_test, y_test_pred))
print("Test ROC_AUC Score:", roc_auc_score(y_test, y_test_prob))
# Out:
# Number of features: 95
# Training Time: 13.621416091918945
# Prediction Time: 1.024709701538086
# Train Accuracy Score: 0.9999411323198281
# Train Confusion Matrix:
#  [[60165     0]
#  [    4  7780]]
#
# Train F1 Score: 0.9997429966589566
# Train Precision Score: 1.0
# Train Recall Score: 0.9994861253854059
# Train ROC_AUC Score: 0.999999998932364
#
# Test Accuracy Score: 0.8855465128257958
# Test Confusion Matrix:
#  [[25778     7]
#  [ 3326    10]]
#
# Test F1 Score: 0.005964807634953773
# Test Precision Score: 0.5882352941176471
# Test Recall Score: 0.002997601918465228
# Test ROC_AUC Score: 0.6344802982512187

# %%
imp = fi_df[fi_df['No_Class_Weight'] >= 0.009]['Features']
print("Number of features:", len(imp))
model = RandomForestClassifier(n_jobs = -1, random_state = 0)
start_time = time.time()
model.fit(X_train[imp], y_train)
end_time = time.time()
print("Training Time:", end_time - start_time)
y_train_pred = model.predict(X_train[imp])
y_train_prob = model.predict_proba(X_train[imp])[:, 1]
start_time = time.time()
y_test_pred = model.predict(X_test[imp])
end_time = time.time()
print("Prediction Time:", end_time - start_time)
y_test_prob = model.predict_proba(X_test[imp])[:, 1]
print("Train Accuracy Score:", accuracy_score(y_train, y_train_pred))
print("Train Confusion Matrix:\n", confusion_matrix(y_train, y_train_pred), '\n')
print("Train F1 Score:", f1_score(y_train, y_train_pred))
print("Train Precision Score:", precision_score(y_train, y_train_pred))
print("Train Recall Score:", recall_score(y_train, y_train_pred))
print("Train ROC_AUC Score:", roc_auc_score(y_train, y_train_prob))
print()
print("Test Accuracy Score:", accuracy_score(y_test, y_test_pred))
print("Test Confusion Matrix:\n", confusion_matrix(y_test, y_test_pred), '\n')
print("Test F1 Score:", f1_score(y_test, y_test_pred))
print("Test Precision Score:", precision_score(y_test, y_test_pred))
print("Test Recall Score:", recall_score(y_test, y_test_pred))
print("Test ROC_AUC Score:", roc_auc_score(y_test, y_test_prob))
# Out:
# Number of features: 30
# Training Time: 7.889331102371216
# Prediction Time: 0.7116963863372803
# Train Accuracy Score: 0.9999411323198281
# Train Confusion Matrix:
#  [[60165     0]
#  [    4  7780]]
#
# Train F1 Score: 0.9997429966589566
# Train Precision Score: 1.0
# Train Recall Score: 0.9994861253854059
# Train ROC_AUC Score: 0.9999999989323639
#
# Test Accuracy Score: 0.8855808523058961
# Test Confusion Matrix:
#  [[25782     3]
#  [ 3329     7]]
#
# Test F1 Score: 0.0041841004184100415
# Test Precision Score: 0.7
# Test Recall Score: 0.0020983213429256594
# Test ROC_AUC Score: 0.6317506785729065

# %% [markdown]
# ### With Class Weight

# %% [markdown]
# #### Balanced

# %%
imp = fi_df[fi_df['Balanced'] >= 0]['Features']
print("Number of features:", len(imp))
model = RandomForestClassifier(n_jobs = -1, random_state = 0, class_weight = 'balanced')
start_time = time.time()
model.fit(X_train[imp], y_train)
end_time = time.time()
print("Training Time:", end_time - start_time)
y_train_pred = model.predict(X_train[imp])
y_train_prob = model.predict_proba(X_train[imp])[:, 1]
start_time = time.time()
y_test_pred = model.predict(X_test[imp])
end_time = time.time()
print("Prediction Time:", end_time - start_time)
y_test_prob = model.predict_proba(X_test[imp])[:, 1]
print("Train Accuracy Score:", accuracy_score(y_train, y_train_pred))
print("Train Confusion Matrix:\n", confusion_matrix(y_train, y_train_pred), '\n')
print("Train F1 Score:", f1_score(y_train, y_train_pred))
print("Train Precision Score:", precision_score(y_train, y_train_pred))
print("Train Recall Score:", recall_score(y_train, y_train_pred))
print("Train ROC_AUC Score:", roc_auc_score(y_train, y_train_prob))
print()
print("Test Accuracy Score:", accuracy_score(y_test, y_test_pred))
print("Test Confusion Matrix:\n", confusion_matrix(y_test, y_test_pred), '\n')
print("Test F1 Score:", f1_score(y_test, y_test_pred))
print("Test Precision Score:", precision_score(y_test, y_test_pred))
print("Test Recall Score:", recall_score(y_test, y_test_pred))
print("Test ROC_AUC Score:", roc_auc_score(y_test, y_test_prob))
# Out:
# Number of features: 95
# Training Time: 12.926573753356934
# Prediction Time: 0.922868013381958
# Train Accuracy Score: 0.9999411323198281
# Train Confusion Matrix:
#  [[60164     1]
#  [    3  7781]]
#
# Train F1 Score: 0.999743029680072
# Train Precision Score: 0.9998714983294783
# Train Recall Score: 0.9996145940390545
# Train ROC_AUC Score: 0.9999996615593517
#
# Test Accuracy Score: 0.8856838707461969
# Test Confusion Matrix:
#  [[25779     6]
#  [ 3323    13]]
#
# Test F1 Score: 0.00774962742175857
# Test Precision Score: 0.6842105263157895
# Test Recall Score: 0.0038968824940047962
# Test ROC_AUC Score: 0.6365730277906819

# %%
imp = fi_df[fi_df['Balanced'] >= 0.009]['Features']
print("Number of features:", len(imp))
model = RandomForestClassifier(n_jobs = -1, random_state = 0, class_weight = 'balanced')
start_time = time.time()
model.fit(X_train[imp], y_train)
end_time = time.time()
print("Training Time:", end_time - start_time)
y_train_pred = model.predict(X_train[imp])
y_train_prob = model.predict_proba(X_train[imp])[:, 1]
start_time = time.time()
y_test_pred = model.predict(X_test[imp])
end_time = time.time()
print("Prediction Time:", end_time - start_time)
y_test_prob = model.predict_proba(X_test[imp])[:, 1]
print("Train Accuracy Score:", accuracy_score(y_train, y_train_pred))
print("Train Confusion Matrix:\n", confusion_matrix(y_train, y_train_pred), '\n')
print("Train F1 Score:", f1_score(y_train, y_train_pred))
print("Train Precision Score:", precision_score(y_train, y_train_pred))
print("Train Recall Score:", recall_score(y_train, y_train_pred))
print("Train ROC_AUC Score:", roc_auc_score(y_train, y_train_prob))
print()
print("Test Accuracy Score:", accuracy_score(y_test, y_test_pred))
print("Test Confusion Matrix:\n", confusion_matrix(y_test, y_test_pred), '\n')
print("Test F1 Score:", f1_score(y_test, y_test_pred))
print("Test Precision Score:", precision_score(y_test, y_test_pred))
print("Test Recall Score:", recall_score(y_test, y_test_pred))
print("Test ROC_AUC Score:", roc_auc_score(y_test, y_test_prob))
# Out:
# Number of features: 30
# Training Time: 8.294874429702759
# Prediction Time: 0.8141505718231201
# Train Accuracy Score: 0.9999558492398711
# Train Confusion Matrix:
#  [[60164     1]
#  [    2  7782]]
#
# Train F1 Score: 0.9998072846405859
# Train Precision Score: 0.999871514840036
# Train Recall Score: 0.999743062692703
# Train ROC_AUC Score: 0.9999997533760575
#
# Test Accuracy Score: 0.8854778338655953
# Test Confusion Matrix:
#  [[25781     4]
#  [ 3331     5]]
#
# Test F1 Score: 0.0029895366218236174
# Test Precision Score: 0.5555555555555556
# Test Recall Score: 0.001498800959232614
# Test ROC_AUC Score: 0.6252348673707921

# %% [markdown]
# #### Balanced Subsample

# %%
imp = fi_df[fi_df['Balanced_Subsample'] >= 0]['Features']
print("Number of features:", len(imp))
model = RandomForestClassifier(n_jobs = -1, random_state = 0, class_weight = 'balanced_subsample')
start_time = time.time()
model.fit(X_train[imp], y_train)
end_time = time.time()
print("Training Time:", end_time - start_time)
y_train_pred = model.predict(X_train[imp])
y_train_prob = model.predict_proba(X_train[imp])[:, 1]
start_time = time.time()
y_test_pred = model.predict(X_test[imp])
end_time = time.time()
print("Prediction Time:", end_time - start_time)
y_test_prob = model.predict_proba(X_test[imp])[:, 1]
print("Train Accuracy Score:", accuracy_score(y_train, y_train_pred))
print("Train Confusion Matrix:\n", confusion_matrix(y_train, y_train_pred), '\n')
print("Train F1 Score:", f1_score(y_train, y_train_pred))
print("Train Precision Score:", precision_score(y_train, y_train_pred))
print("Train Recall Score:", recall_score(y_train, y_train_pred))
print("Train ROC_AUC Score:", roc_auc_score(y_train, y_train_prob))
print()
print("Test Accuracy Score:", accuracy_score(y_test, y_test_pred))
print("Test Confusion Matrix:\n", confusion_matrix(y_test, y_test_pred), '\n')
print("Test F1 Score:", f1_score(y_test, y_test_pred))
print("Test Precision Score:", precision_score(y_test, y_test_pred))
print("Test Recall Score:", recall_score(y_test, y_test_pred))
print("Test ROC_AUC Score:", roc_auc_score(y_test, y_test_prob))
# Out:
# Number of features: 95
# Training Time: 14.563291072845459
# Prediction Time: 0.9247901439666748
# Train Accuracy Score: 0.9999411323198281
# Train Confusion Matrix:
#  [[60164     1]
#  [    3  7781]]
#
# Train F1 Score: 0.999743029680072
# Train Precision Score: 0.9998714983294783
# Train Recall Score: 0.9996145940390545
# Train ROC_AUC Score: 0.9999996594240794
#
# Test Accuracy Score: 0.885443494385495
# Test Confusion Matrix:
#  [[25777     8]
#  [ 3328     8]]
#
# Test F1 Score: 0.00477326968973747
# Test Precision Score: 0.5
# Test Recall Score: 0.002398081534772182
# Test ROC_AUC Score: 0.6343718277268819

# %%
imp = fi_df[fi_df['Balanced_Subsample'] >= 0.009]['Features']
print("Number of features:", len(imp))
model = RandomForestClassifier(n_jobs = -1, random_state = 0, class_weight = 'balanced_subsample')
start_time = time.time()
model.fit(X_train[imp], y_train)
end_time = time.time()
print("Training Time:", end_time - start_time)
y_train_pred = model.predict(X_train[imp])
y_train_prob = model.predict_proba(X_train[imp])[:, 1]
start_time = time.time()
y_test_pred = model.predict(X_test[imp])
end_time = time.time()
print("Prediction Time:", end_time - start_time)
y_test_prob = model.predict_proba(X_test[imp])[:, 1]
print("Train Accuracy Score:", accuracy_score(y_train, y_train_pred))
print("Train Confusion Matrix:\n", confusion_matrix(y_train, y_train_pred), '\n')
print("Train F1 Score:", f1_score(y_train, y_train_pred))
print("Train Precision Score:", precision_score(y_train, y_train_pred))
print("Train Recall Score:", recall_score(y_train, y_train_pred))
print("Train ROC_AUC Score:", roc_auc_score(y_train, y_train_prob))
print()
print("Test Accuracy Score:", accuracy_score(y_test, y_test_pred))
print("Test Confusion Matrix:\n", confusion_matrix(y_test, y_test_pred), '\n')
print("Test F1 Score:", f1_score(y_test, y_test_pred))
print("Test Precision Score:", precision_score(y_test, y_test_pred))
print("Test Recall Score:", recall_score(y_test, y_test_pred))
print("Test ROC_AUC Score:", roc_auc_score(y_test, y_test_prob))
# Out:
# Number of features: 30
# Training Time: 9.56050419807434
# Prediction Time: 0.7116415500640869
# Train Accuracy Score: 0.9999411323198281
# Train Confusion Matrix:
#  [[60164     1]
#  [    3  7781]]
#
# Train F1 Score: 0.999743029680072
# Train Precision Score: 0.9998714983294783
# Train Recall Score: 0.9996145940390545
# Train ROC_AUC Score: 0.9999998644102134
#
# Test Accuracy Score: 0.8853404759451942
# Test Confusion Matrix:
#  [[25778     7]
#  [ 3332     4]]
#
# Test F1 Score: 0.0023902001792650133
# Test Precision Score: 0.36363636363636365
# Test Recall Score: 0.001199040767386091
# Test ROC_AUC Score: 0.6283022215153997

# %% [markdown]
# ### Sampling Techniques

# %% [markdown]
# #### Under Sampling

# %%
rus = RandomUnderSampler(random_state = 0)
X_rus, y_rus = rus.fit_resample(X_train[imp], y_train)
model = RandomForestClassifier(random_state = 0, n_jobs = -1)
model.fit(X_rus, y_rus)
pred = model.predict(X_test[imp])
prob = model.predict_proba(X_test[imp])[:, 1]
print(confusion_matrix(y_test, pred))
print(classification_report(y_test, pred))
print("ROC_AUC:", roc_auc_score(y_test, prob))
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# [[15582 10203]
#  [ 1377  1959]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.60      0.73     25785
#            1       0.16      0.59      0.25      3336
#
#     accuracy                           0.60     29121
#    macro avg       0.54      0.60      0.49     29121
# weighted avg       0.83      0.60      0.67     29121
#
# ROC_AUC: 0.6322889216259336

# %%
rus = RandomUnderSampler(random_state = 0)
X_rus, y_rus = rus.fit_resample(X_train[imp], y_train)
model = RandomForestClassifier(random_state = 0, n_jobs = -1, class_weight = 'balanced_subsample')
model.fit(X_rus, y_rus)
pred = model.predict(X_test[imp])
prob = model.predict_proba(X_test[imp])[:, 1]
print(confusion_matrix(y_test, pred))
print(classification_report(y_test, pred))
print("ROC_AUC:", roc_auc_score(y_test, prob))
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# [[15623 10162]
#  [ 1387  1949]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.61      0.73     25785
#            1       0.16      0.58      0.25      3336
#
#     accuracy                           0.60     29121
#    macro avg       0.54      0.60      0.49     29121
# weighted avg       0.83      0.60      0.68     29121
#
# ROC_AUC: 0.6346809754058301

# %% [markdown]
# #### Over Sampling

# %%
ros = RandomOverSampler(random_state = 0)
X_ros, y_ros = ros.fit_resample(X_train[imp], y_train)
model = RandomForestClassifier(random_state = 0, n_jobs = -1)
model.fit(X_ros, y_ros)
pred = model.predict(X_test[imp])
prob = model.predict_proba(X_test[imp])[:, 1]
print(confusion_matrix(y_test, pred))
print(classification_report(y_test, pred))
print("ROC_AUC:", roc_auc_score(y_test, prob))
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# [[25689    96]
#  [ 3278    58]]
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94     25785
#            1       0.38      0.02      0.03      3336
#
#     accuracy                           0.88     29121
#    macro avg       0.63      0.51      0.49     29121
# weighted avg       0.83      0.88      0.83     29121
#
# ROC_AUC: 0.6280131392268384

# %%
ros = RandomOverSampler(random_state = 0)
X_ros, y_ros = ros.fit_resample(X_train[imp], y_train)
model = RandomForestClassifier(random_state = 0, n_jobs = -1, class_weight = 'balanced_subsample')
model.fit(X_ros, y_ros)
pred = model.predict(X_test[imp])
prob = model.predict_proba(X_test[imp])[:, 1]
print(confusion_matrix(y_test, pred))
print(classification_report(y_test, pred))
print("ROC_AUC:", roc_auc_score(y_test, prob))
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# [[25692    93]
#  [ 3284    52]]
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94     25785
#            1       0.36      0.02      0.03      3336
#
#     accuracy                           0.88     29121
#    macro avg       0.62      0.51      0.48     29121
# weighted avg       0.83      0.88      0.83     29121
#
# ROC_AUC: 0.6252679589894111

# %% [markdown]
# #### SMOTE

# %%
sm = SMOTE(random_state = 0, n_jobs = -1)
X_sm, y_sm = sm.fit_resample(X_train[imp], y_train)
model = RandomForestClassifier(random_state = 0, n_jobs = -1)
model.fit(X_sm, y_sm)
pred = model.predict(X_test[imp])
prob = model.predict_proba(X_test[imp])[:, 1]
print(confusion_matrix(y_test, pred))
print(classification_report(y_test, pred))
print("ROC_AUC:", roc_auc_score(y_test, prob))
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# [[23574  2211]
#  [ 2998   338]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.91      0.90     25785
#            1       0.13      0.10      0.11      3336
#
#     accuracy                           0.82     29121
#    macro avg       0.51      0.51      0.51     29121
# weighted avg       0.80      0.82      0.81     29121
#
# ROC_AUC: 0.5673032719839253

# %%
sm = SMOTE(random_state = 0, n_jobs = -1)
X_sm, y_sm = sm.fit_resample(X_train[imp], y_train)
model = RandomForestClassifier(random_state = 0, n_jobs = -1, class_weight = 'balanced_subsample')
model.fit(X_sm, y_sm)
pred = model.predict(X_test[imp])
prob = model.predict_proba(X_test[imp])[:, 1]
print(confusion_matrix(y_test, pred))
print(classification_report(y_test, pred))
print("ROC_AUC:", roc_auc_score(y_test, prob))
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# [[23575  2210]
#  [ 2995   341]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.91      0.90     25785
#            1       0.13      0.10      0.12      3336
#
#     accuracy                           0.82     29121
#    macro avg       0.51      0.51      0.51     29121
# weighted avg       0.80      0.82      0.81     29121
#
# ROC_AUC: 0.5661021793385536

# %% [markdown]
# #### SmoteTomek

# %%
smtmk = SMOTETomek(random_state = 0)
X_smtmk, y_smtmk = sm.fit_resample(X_train[imp], y_train)
model = RandomForestClassifier(random_state = 0, n_jobs = -1)
model.fit(X_smtmk, y_smtmk)
pred = model.predict(X_test[imp])
prob = model.predict_proba(X_test[imp])[:, 1]
print(confusion_matrix(y_test, pred))
print(classification_report(y_test, pred))
print("ROC_AUC:", roc_auc_score(y_test, prob))
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# [[23574  2211]
#  [ 2998   338]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.91      0.90     25785
#            1       0.13      0.10      0.11      3336
#
#     accuracy                           0.82     29121
#    macro avg       0.51      0.51      0.51     29121
# weighted avg       0.80      0.82      0.81     29121
#
# ROC_AUC: 0.5673032719839253

# %%
smtmk = SMOTETomek(random_state = 0)
X_smtmk, y_smtmk = sm.fit_resample(X_train[imp], y_train)
model = RandomForestClassifier(random_state = 0, n_jobs = -1, class_weight = 'balanced_subsample')
model.fit(X_smtmk, y_smtmk)
pred = model.predict(X_test[imp])
prob = model.predict_proba(X_test[imp])[:, 1]
print(confusion_matrix(y_test, pred))
print(classification_report(y_test, pred))
print("ROC_AUC:", roc_auc_score(y_test, prob))
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# [[23575  2210]
#  [ 2995   341]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.91      0.90     25785
#            1       0.13      0.10      0.12      3336
#
#     accuracy                           0.82     29121
#    macro avg       0.51      0.51      0.51     29121
# weighted avg       0.80      0.82      0.81     29121
#
# ROC_AUC: 0.5661021793385536

# %% [markdown]
# ### Hyper-Parameter Tuning

# %%
X_rus.shape, y_rus.sum()
# Out:
# ((15568, 25), 7784)

# %%
model = RandomForestClassifier(random_state = 0, n_jobs = -1)
params = {'n_estimators' : randint(100, 1000),
          'criterion' : ['gini', 'entropy'],
          'max_depth' : randint(1, 50),
          'min_samples_split' : randint(2, 25),
          'min_samples_leaf' : randint(1, 25),
          'max_features' : randint(1, 25),
          'bootstrap' : ['True', 'False']}
rsearch = RandomizedSearchCV(model, params, n_iter = 10, scoring = 'recall', n_jobs = -1,
                             cv = 5, verbose = 2, random_state = 0)
rsearch.fit(X_rus, y_rus)

# %%
rsearch.best_score_, rsearch.best_params_
# Out:
# (0.622302546093354,
#  {'bootstrap': 'False',
#   'criterion': 'gini',
#   'max_depth': 12,
#   'max_features': 19,
#   'min_samples_leaf': 24,
#   'min_samples_split': 4,
#   'n_estimators': 228})

# %%
model = RandomForestClassifier(random_state = 0, n_jobs = -1)
params = {'n_estimators' : randint(200, 300),
          'criterion' : ['gini', 'entropy'],
          'max_depth' : randint(5, 20),
          'min_samples_split' : randint(2, 10),
          'min_samples_leaf' : randint(20, 50),
          'max_features' : randint(10, 25),
          'bootstrap' : ['True', 'False']}
rsearch = RandomizedSearchCV(model, params, n_iter = 50, scoring = 'recall', n_jobs = -1,
                             cv = 5, verbose = 1, random_state = 0)
rsearch.fit(X_rus, y_rus)
rsearch.best_score_, rsearch.best_params_
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done 196 tasks      | elapsed: 12.3min
# [Parallel(n_jobs=-1)]: Done 250 out of 250 | elapsed: 15.6min finished
# (0.6248720844416046,
#  {'bootstrap': 'True',
#   'criterion': 'gini',
#   'max_depth': 16,
#   'max_features': 10,
#   'min_samples_leaf': 34,
#   'min_samples_split': 5,
#   'n_estimators': 253})

# %%
model = rsearch.best_estimator_
model.fit(X_rus, y_rus)
pred = model.predict(X_test[imp])
prob = model.predict_proba(X_test[imp])[:, 1]
print(confusion_matrix(y_test, pred))
print(classification_report(y_test, pred))
print("ROC_AUC:", roc_auc_score(y_test, prob))
# Out:
# [[15400 10385]
#  [ 1246  2090]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.60      0.73     25785
#            1       0.17      0.63      0.26      3336
#
#     accuracy                           0.60     29121
#    macro avg       0.55      0.61      0.50     29121
# weighted avg       0.84      0.60      0.67     29121
#
# ROC_AUC: 0.6543836774675664
