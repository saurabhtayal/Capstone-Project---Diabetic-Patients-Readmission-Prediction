# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_curve, precision_recall_curve, classification_report, confusion_matrix
from sklearn.metrics import recall_score, precision_score, f1_score, accuracy_score, roc_auc_score
import time
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/My Drive/PGPDSE/Capstone/CSV Files/Diabetes_Preprocessed_Before_Feature_Selection.csv')
df.head()
# Out:
#               race  gender  age discharge_disposition_id admission_source_id  \
# 0        Caucasian       0    5            Not Available            Referral
# 1        Caucasian       0   15       Discharged to home           Emergency
# 2  AfricanAmerican       0   25       Discharged to home           Emergency
# 3        Caucasian       1   35       Discharged to home           Emergency
# 4        Caucasian       1   45       Discharged to home           Emergency
#
#    time_in_hospital  num_lab_procedures  num_procedures  num_medications  \
# 0                 1                  41               0                1
# 1                 3                  59               0               18
# 2                 2                  11               5               13
# 3                 2                  44               1               16
# 4                 1                  51               0                8
#
#                                         diag_1        diag_2  \
# 0                                     Diabetes  Not Required
# 1  Endocrine, Nutritional, Metabolic, Immunity      Diabetes
# 2                        Pregnancy, Childbirth      Diabetes
# 3                     Infectious and Parasitic      Diabetes
# 4                                    Neoplasms     Neoplasms
#
#                                         diag_3  number_diagnoses  \
# 0                                 Not Required                 1
# 1  Endocrine, Nutritional, Metabolic, Immunity                 9
# 2                    External causes of injury                 6
# 3                                  Circulatory                 7
# 4                                     Diabetes                 5
#
#   max_glu_serum A1Cresult  metformin  repaglinide  glimepiride  glipizide  \
# 0          None      None         -2           -2           -2         -2
# 1          None      None         -2           -2           -2         -2
# 2          None      None         -2           -2           -2          0
# 3          None      None         -2           -2           -2         -2
# 4          None      None         -2           -2           -2          0
#
#    glyburide  pioglitazone  rosiglitazone  insulin  diabetesMed  readmitted  \
# 0         -2            -2             -2       -2            0           0
# 1         -2            -2             -2        1            1           0
# 2         -2            -2             -2       -2            1           0
# 3         -2            -2             -2        1            1           0
# 4         -2            -2             -2        0            1           0
#
#    preceding_year_visits  number_changes insulin_treatment
# 0                      0               0            no_med
# 1                      0               1      insulin_only
# 2                      3               0        other_meds
# 3                      0               1      insulin_only
# 4                      0               0     insulin_combo

# %%
df.shape
# Out:
# (97070, 28)

# %%
X = df.drop('readmitted', 1)
y = df['readmitted']
X_dum = pd.get_dummies(X, drop_first = True)
X_train, X_test, y_train, y_test = train_test_split(X_dum, y, test_size = 0.3, stratify = y, random_state = 0)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((67949, 95), (29121, 95), (67949,), (29121,))

# %% [markdown]
# ### Default Decision Tree with class weight

# %%
model = DecisionTreeClassifier(random_state = 0, class_weight = 'balanced')
model.fit(X_train, y_train)
sorted(zip(model.feature_importances_, X_train.columns), reverse = True)
# Out:
# [(0.12365442164036872, 'num_lab_procedures'),
#  (0.11372636536368964, 'num_medications'),
#  (0.06390367863223807, 'time_in_hospital'),
#  (0.05042546073138741, 'preceding_year_visits'),
#  (0.04697597986166735, 'age'),
#  (0.04083221673070613, 'num_procedures'),
#  (0.04053462174770501, 'number_diagnoses'),
#  (0.019795677948474092, 'insulin'),
#  (0.019714341130940054,
#   'discharge_disposition_id_Transferred to another medical facility'),
#  (0.015839912478576138, 'race_Caucasian'),
#  (0.014140805503156769, 'diag_3_Circulatory'),
#  (0.013267240400954844, 'admission_source_id_Referral'),
#  (0.013253323481257273, 'diag_1_Circulatory'),
#  (0.012905064547135187, 'diag_2_Circulatory'),
#  (0.012632933443806543, 'gender'),
#  (0.012450851695309047, 'number_changes'),
#  (0.01171835396610171, 'glyburide'),
#  (0.011100828594193526, 'diag_3_Endocrine, Nutritional, Metabolic, Immunity'),
#  (0.010623295164622026, 'diag_3_Diabetes'),
#  (0.010368378921011468, 'diag_1_Respiratory'),
#  (0.010047383644997531, 'metformin'),
#  (0.00981609992152582, 'glipizide'),
#  (0.009507708740242404, 'pioglitazone'),
#  (0.009178694787153635, 'diag_3_Genitourinary'),
#  (0.009142884257493633,
#   'discharge_disposition_id_Discharged to home with home health service'),
#  (0.008760249909011314, 'diag_1_Digestive'),
#  (0.008735447587705005, 'rosiglitazone'),
#  (0.008672358987324939, 'diag_2_Respiratory'),
#  (0.008386278917746473, 'diag_2_Endocrine, Nutritional, Metabolic, Immunity'),
#  (0.00804276008634421, 'A1Cresult_None'),
#  (0.007678459035227401, 'diag_1_Injury and Poisoning'),
#  (0.00767752291171954, 'diag_1_Genitourinary'),
#  (0.007601273810048608, 'diag_3_Respiratory'),
#  (0.0075744876084143774, 'insulin_treatment_insulin_only'),
#  (0.007543703400257279, 'diag_2_Diabetes'),
#  (0.007514922113443145, 'diag_2_Genitourinary'),
#  (0.007364975326090615, 'diag_3_External causes of injury'),
#  (0.006988446699991259, 'diag_1_Diabetes'),
#  (0.00692388406739829, 'glimepiride'),
#  (0.0064997199502524845, 'diag_3_Digestive'),
#  (0.006243022095635588, 'insulin_treatment_other_meds'),
#  (0.005894946284875565, 'A1Cresult_Norm'),
#  (0.005878486341601492, 'A1Cresult_>8'),
#  (0.005853142455337708, 'diag_1_Infectious and Parasitic'),
#  (0.0058207421467214755, 'diag_2_Digestive'),
#  (0.005430064292085688, 'diag_2_Mental Disorders'),
#  (0.005380327545067759, 'insulin_treatment_no_med'),
#  (0.005344675231955721, 'diag_3_Skin and Subcutaneous Tissue'),
#  (0.005299296957580616, 'diag_1_Skin and Subcutaneous Tissue'),
#  (0.005141236987435291, 'diag_1_Neoplasms'),
#  (0.005106075800139764, 'diag_1_Endocrine, Nutritional, Metabolic, Immunity'),
#  (0.005065962709966822, 'diag_2_External causes of injury'),
#  (0.0049791759112431284,
#   'diag_1_Musculoskeletal System and Connective Tissue'),
#  (0.004977046480360772, 'discharge_disposition_id_Not Available'),
#  (0.00496607562957799,
#   'admission_source_id_Transferred from another health care facility'),
#  (0.004651122102571166, 'diag_2_Skin and Subcutaneous Tissue'),
#  (0.004511271130732826, 'diag_3_Mental Disorders'),
#  (0.004467215312355025, 'diag_1_Other Symptoms'),
#  (0.004459398704494575, 'admission_source_id_Not Available'),
#  (0.004292014951329533, 'repaglinide'),
#  (0.0042492134225792086, 'max_glu_serum_None'),
#  (0.004197621065199136, 'diag_1_Mental Disorders'),
#  (0.004155121955415763, 'diag_3_Other Symptoms'),
#  (0.00411444167797562, 'diag_2_Neoplasms'),
#  (0.003977522891545203, 'diag_2_Other Symptoms'),
#  (0.0037822595767603114, 'diag_2_Injury and Poisoning'),
#  (0.0037758103679487415, 'diag_3_Infectious and Parasitic'),
#  (0.0035462800311967762, 'race_Other'),
#  (0.003307975361781451, 'diabetesMed'),
#  (0.0031985862282912472, 'diag_2_Infectious and Parasitic'),
#  (0.003099991645511938, 'diag_3_Nervous'),
#  (0.003075135121942618, 'diag_3_Injury and Poisoning'),
#  (0.002994057271016412, 'diag_3_Neoplasms'),
#  (0.002724868334586657, 'race_Hispanic'),
#  (0.0024166641142292886, 'max_glu_serum_Norm'),
#  (0.00226837821052154, 'diag_2_Musculoskeletal System and Connective Tissue'),
#  (0.002221707295874767, 'diag_3_Musculoskeletal System and Connective Tissue'),
#  (0.002161016219148554, 'diag_2_Nervous'),
#  (0.0020733460035096615, 'diag_1_Congenital Anomalies'),
#  (0.0018830354093682692, 'diag_1_External causes of injury'),
#  (0.0017059573189136803, 'max_glu_serum_>300'),
#  (0.0016698672895812557, 'diag_3_Congenital Anomalies'),
#  (0.0016264672958053793, 'discharge_disposition_id_Left AMA'),
#  (0.0011120694322418628, 'race_Asian'),
#  (0.001082321095171615, 'diag_1_Nervous'),
#  (0.0007295589375864737,
#   'discharge_disposition_id_Still patient/referred to this institution'),
#  (0.0007271008629802439, 'diag_2_Congenital Anomalies'),
#  (0.0007124264878698417, 'diag_1_Pregnancy, Childbirth'),
#  (0.000573893356271633, 'diag_2_Pregnancy, Childbirth'),
#  (0.0005683182883186903, 'diag_3_Not Required'),
#  (0.00036563520903042454, 'diag_1_Sense Organs'),
#  (0.00031331026138137604, 'diag_3_Sense Organs'),
#  (0.00015132229747390766, 'diag_2_Not Required'),
#  (0.0001011359360457473, 'diag_2_Sense Organs'),
#  (5.527091016713499e-05, 'diag_3_Pregnancy, Childbirth')]

# %%
fi_df = pd.DataFrame({"Feature" : X_train.columns, "Importance" : model.feature_importances_})
imp = fi_df[fi_df['Importance'] >= 0]['Feature']
len(imp)
# Out:
# 95

# %%
model = DecisionTreeClassifier(random_state = 0, class_weight = 'balanced')
start_time = time.time()
model.fit(X_train[imp], y_train)
end_time = time.time()
print("Training Time:", end_time - start_time)
y_train_pred = model.predict(X_train[imp])
y_train_prob = model.predict_proba(X_train[imp])[:, 1]
start_time = time.time()
y_test_pred = model.predict(X_test[imp])
end_time = time.time()
print("Prediction Time:", end_time - start_time)
y_test_prob = model.predict_proba(X_test[imp])[:, 1]
print("Train Accuracy Score:", accuracy_score(y_train, y_train_pred))
print("Train Confusion Matrix:\n", confusion_matrix(y_train, y_train_pred), '\n')
print("Train F1 Score:", f1_score(y_train, y_train_pred))
print("Train Precision Score:", precision_score(y_train, y_train_pred))
print("Train Recall Score:", recall_score(y_train, y_train_pred))
print("Train ROC_AUC Score:", roc_auc_score(y_train, y_train_prob))
print()
print("Test Accuracy Score:", accuracy_score(y_test, y_test_pred))
print("Test Confusion Matrix:\n", confusion_matrix(y_test, y_test_pred), '\n')
print("Test F1 Score:", f1_score(y_test, y_test_pred))
print("Test Precision Score:", precision_score(y_test, y_test_pred))
print("Test Recall Score:", recall_score(y_test, y_test_pred))
print("Test ROC_AUC Score:", roc_auc_score(y_test, y_test_prob))
# Out:
# Training Time: 1.3760809898376465
# Prediction Time: 0.02542257308959961
# Train Accuracy Score: 0.999985283079957
# Train Confusion Matrix:
#  [[60164     1]
#  [    0  7784]]
#
# Train F1 Score: 0.9999357697989595
# Train Precision Score: 0.9998715478484265
# Train Recall Score: 1.0
# Train ROC_AUC Score: 0.9999999989323639
#
# Test Accuracy Score: 0.797980838570104
# Test Confusion Matrix:
#  [[22649  3136]
#  [ 2747   589]]
#
# Test F1 Score: 0.1668318934995043
# Test Precision Score: 0.1581208053691275
# Test Recall Score: 0.17655875299760193
# Test ROC_AUC Score: 0.5274688277301371
