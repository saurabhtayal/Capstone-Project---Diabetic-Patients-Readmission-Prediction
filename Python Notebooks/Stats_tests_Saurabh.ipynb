# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
from statsmodels.stats.anova import anova_lm
import scipy.stats as stats

# %%
df = pd.read_csv('/content/drive/My Drive/PGPDSE/Capstone/CSV Files/Diabetes_Preprocessed.csv')
df.head()
# Out:
#               race  gender  ...  number_changes insulin_treatment
# 0        Caucasian       0  ...               0            no_med
# 1        Caucasian       0  ...               1      insulin_only
# 2  AfricanAmerican       0  ...               0        other_meds
# 3        Caucasian       1  ...               1      insulin_only
# 4        Caucasian       1  ...               0     insulin_combo
#
# [5 rows x 47 columns]

# %%
df.columns
# Out:
# Index(['race', 'gender', 'age', 'admission_type_id',
#        'discharge_disposition_id', 'admission_source_id', 'time_in_hospital',
#        'num_lab_procedures', 'num_procedures', 'num_medications',
#        'number_outpatient', 'number_emergency', 'number_inpatient', 'diag_1',
#        'diag_2', 'diag_3', 'number_diagnoses', 'max_glu_serum', 'A1Cresult',
#        'metformin', 'repaglinide', 'nateglinide', 'chlorpropamide',
#        'glimepiride', 'acetohexamide', 'glipizide', 'glyburide', 'tolbutamide',
#        'pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 'troglitazone',
#        'tolazamide', 'insulin', 'glyburide-metformin', 'glipizide-metformin',
#        'glimepiride-pioglitazone', 'metformin-rosiglitazone',
#        'metformin-pioglitazone', 'change', 'diabetesMed', 'readmitted',
#        'preceding_year_visits', 'number_diab_meds', 'number_changes',
#        'insulin_treatment'],
#       dtype='object')

# %%
num_cols = ['age', 'time_in_hospital', 'num_lab_procedures', 'num_procedures', 'num_medications',
       'number_outpatient', 'number_emergency', 'number_inpatient', 'number_diagnoses',
       'metformin', 'repaglinide', 'nateglinide', 'chlorpropamide', 'glimepiride', 'acetohexamide', 
       'glipizide', 'glyburide', 'tolbutamide', 'pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 
       'troglitazone', 'tolazamide', 'insulin', 'glyburide-metformin', 'glipizide-metformin',
       'glimepiride-pioglitazone', 'metformin-rosiglitazone', 'metformin-pioglitazone',
       'preceding_year_visits', 'number_diab_meds', 'number_changes']

# %%
cat_cols = ['race', 'gender', 'admission_type_id', 'discharge_disposition_id', 'admission_source_id',
            'diag_1', 'diag_2', 'diag_3', 'max_glu_serum', 'A1Cresult', 'metformin', 'repaglinide', 
            'nateglinide', 'chlorpropamide', 'glimepiride', 'acetohexamide', 'glipizide', 'glyburide', 
            'tolbutamide', 'pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 'troglitazone',
            'tolazamide', 'insulin', 'glyburide-metformin', 'glipizide-metformin', 
            'glimepiride-pioglitazone', 'metformin-rosiglitazone', 'metformin-pioglitazone', 
            'change', 'diabetesMed', 'insulin_treatment']

# %%
signi = []
insigni = []

# %%
for i in num_cols:
    stat, p = stats.f_oneway(df[df['readmitted'] == 0][i], df[df['readmitted'] == 1][i])
    print(i, p)
    if p < 0.05:
        signi.append(i)
    else:
        insigni.append(i)
# Out:
# age 3.275693601299605e-11
# time_in_hospital 6.893070040748984e-49
# num_lab_procedures 3.50324799243207e-14
# num_procedures 0.0015300709318757395
# num_medications 1.1288468668441138e-39
# number_outpatient 2.6036109840101055e-09
# number_emergency 1.4249170045527198e-80
# number_inpatient 0.0
# number_diagnoses 1.1811131216158576e-62
# metformin 6.618863230577273e-17
# repaglinide 0.004353482755461344
# nateglinide 0.8771288794322919
# chlorpropamide 0.11189625925085016
# glimepiride 0.009866916697970107
# acetohexamide 0.7190802852468501
# glipizide 0.6014164263983024
# glyburide 0.03411210070648465
# tolbutamide 0.36463043780687776
# pioglitazone 0.03060523702735831
# rosiglitazone 0.026249553129168154
# acarbose 0.2711864808969542
# miglitol 0.5405654274080125
# troglitazone 0.5332811409035749
# tolazamide 0.4503258670986594
# insulin 7.545322631658041e-19
# glyburide-metformin 0.5415005293627841
# glipizide-metformin 0.6700583431360063
# glimepiride-pioglitazone 0.7190802852468501
# metformin-rosiglitazone nan
# metformin-pioglitazone 0.7190802852468501
# preceding_year_visits 0.0
# number_diab_meds 0.8102124453045834
# number_changes 3.6274197674230404e-30
# /usr/local/lib/python3.6/dist-packages/scipy/stats/stats.py:3349: RuntimeWarning: invalid value encountered in double_scalars
#   f = msb / msw

# %%
for i in cat_cols:
    ct = pd.crosstab(df[i], df['readmitted'])
    stat, p, dof, exp = stats.chi2_contingency(ct)
    print(i, p)
    if p < 0.05:
        signi.append(i)
    else:
        insigni.append(i)
# Out:
# race 0.12631048686617366
# gender 0.40957392505802603
# admission_type_id 6.554917297271167e-08
# discharge_disposition_id 1.002864760541056e-175
# admission_source_id 1.9378459310899318e-09
# diag_1 7.6420466996299705e-28
# diag_2 1.2293374159584854e-19
# diag_3 5.426863939357557e-30
# max_glu_serum 0.00026821722868339997
# A1Cresult 1.1503950837008265e-08
# metformin 2.759957036098958e-15
# repaglinide 0.010010257207815234
# nateglinide 0.6970632986594952
# chlorpropamide 0.4419944611352624
# glimepiride 0.042038750915917335
# acetohexamide 0.22618558444301518
# glipizide 0.00607889757478543
# glyburide 0.11434821601815241
# tolbutamide 0.578549828651995
# pioglitazone 0.04487769290652804
# rosiglitazone 0.07245005605017524
# acarbose 0.238986848061409
# miglitol 0.16886381144958132
# troglitazone 0.7768704267049937
# tolazamide 0.7391045739438008
# insulin 1.4500244485830567e-43
# glyburide-metformin 0.7088183082991447
# glipizide-metformin 0.9925194752820149
# glimepiride-pioglitazone 0.22618558444301518
# metformin-rosiglitazone 1.0
# metformin-pioglitazone 0.22618558444301518
# change 4.233462581369607e-09
# diabetesMed 2.9493612448914164e-16
# insulin_treatment 1.750134550082863e-39

# %%
num_cols = ['age', 'time_in_hospital', 'num_lab_procedures', 'num_procedures', 'num_medications', 'number_outpatient', 'number_emergency',
 'number_inpatient', 'number_diagnoses','preceding_year_visits', 'number_diab_meds', 'number_changes']

# %%
p_val = []
sig = []
for i in df.columns:
    if i in num_cols:
        stat, p = stats.f_oneway(df[df['readmitted'] == 0][i], df[df['readmitted'] == 1][i])
    else:
        ct = pd.crosstab(df[i], df['readmitted'])
        stat, p, dof, exp = stats.chi2_contingency(ct)
    p_val.append(p)
    if p < 0.05:
        sig.append('Significant')
    else:
        sig.append("Insignificant")
stats_df = pd.DataFrame({"columns" : df.columns, "p_value" : p_val, "significance" : sig})
stats_df.T
# Out:
#                          0              1   ...              45                 46
# columns                race         gender  ...  number_changes  insulin_treatment
# p_value             0.12631       0.409574  ...     3.62742e-30        1.75013e-39
# significance  Insignificant  Insignificant  ...     Significant        Significant
#
# [3 rows x 47 columns]

# %%
for i in cat_cols:
    print(df[i].value_counts(), '\n')
# Out:
# Caucasian          74201
# AfricanAmerican    18759
# Hispanic            2012
# Other               1471
# Asian                627
# Name: race, dtype: int64
#
# 0    52321
# 1    44749
# Name: gender, dtype: int64
#
# Emergency        70595
# Elective         18305
# Not Available     8170
# Name: admission_type_id, dtype: int64
#
# Discharged to home                             58751
# Transferred to another medical facility        20167
# Discharged to home with home health service    12797
# Not Available                                   4644
# Left AMA                                         610
# Still patient/referred to this institution       101
# Name: discharge_disposition_id, dtype: int64
#
# Emergency                                        55994
# Referral                                         29712
# Transferred from another health care facility     5703
# Not Available                                     5661
# Name: admission_source_id, dtype: int64
#
# Circulatory                                     29004
# Respiratory                                     13624
# Digestive                                        9154
# Diabetes                                         8471
# Injury and Poisoning                             6699
# Genitourinary                                    4912
# Musculoskeletal System and Connective Tissue     4801
# Neoplasms                                        2893
# Endocrine, Nutritional, Metabolic, Immunity      2553
# Skin and Subcutaneous Tissue                     2536
# Infectious and Parasitic                         2487
# Other Symptoms                                   2474
# Mental Disorders                                 2174
# External causes of injury                        1595
# Blood and Blood-Forming Organs                   1078
# Nervous                                           902
# Congenital Anomalies                              791
# Pregnancy, Childbirth                             668
# Sense Organs                                      254
# Name: diag_1, dtype: int64
#
# Circulatory                                     30463
# Diabetes                                        12389
# Respiratory                                     10165
# Genitourinary                                    8001
# Endocrine, Nutritional, Metabolic, Immunity      7896
# Digestive                                        3994
# Skin and Subcutaneous Tissue                     3499
# Blood and Blood-Forming Organs                   2801
# Mental Disorders                                 2570
# External causes of injury                        2483
# Other Symptoms                                   2314
# Injury and Poisoning                             2301
# Neoplasms                                        2246
# Infectious and Parasitic                         1815
# Musculoskeletal System and Connective Tissue     1711
# Nervous                                          1048
# Congenital Anomalies                              478
# Pregnancy, Childbirth                             406
# Not Required                                      334
# Sense Organs                                      156
# Name: diag_2, dtype: int64
#
# Circulatory                                     28947
# Diabetes                                        16538
# Endocrine, Nutritional, Metabolic, Immunity      8726
# Respiratory                                      6857
# Genitourinary                                    6287
# External causes of injury                        4937
# Digestive                                        3781
# Mental Disorders                                 3027
# Skin and Subcutaneous Tissue                     2495
# Blood and Blood-Forming Organs                   2402
# Other Symptoms                                   2267
# Musculoskeletal System and Connective Tissue     1846
# Injury and Poisoning                             1845
# Infectious and Parasitic                         1773
# Neoplasms                                        1577
# Nervous                                          1398
# Not Required                                     1345
# Congenital Anomalies                              467
# Pregnancy, Childbirth                             301
# Sense Organs                                      254
# Name: diag_3, dtype: int64
#
# None    91978
# Norm     2517
# >200     1397
# >300     1178
# Name: max_glu_serum, dtype: int64
#
# None    80662
# >8       7881
# Norm     4836
# >7       3691
# Name: A1Cresult, dtype: int64
#
# -2    77697
#  0    17777
#  1     1035
# -1      561
# Name: metformin, dtype: int64
#
# -2    95562
#  0     1359
#  1      106
# -1       43
# Name: repaglinide, dtype: int64
#
# -2    96389
#  0      647
#  1       23
# -1       11
# Name: nateglinide, dtype: int64
#
# -2    96987
#  0       76
#  1        6
# -1        1
# Name: chlorpropamide, dtype: int64
#
# -2    92105
#  0     4466
#  1      316
# -1      183
# Name: glimepiride, dtype: int64
#
# -2    97069
#  0        1
# Name: acetohexamide, dtype: int64
#
# -2    84827
#  0    10963
#  1      748
# -1      532
# Name: glipizide, dtype: int64
#
# -2    86820
#  0     8925
#  1      783
# -1      542
# Name: glyburide, dtype: int64
#
# -2    97050
#  0       20
# Name: tolbutamide, dtype: int64
#
# -2    89970
#  0     6758
#  1      226
# -1      116
# Name: pioglitazone, dtype: int64
#
# -2    90907
#  0     5913
#  1      168
# -1       82
# Name: rosiglitazone, dtype: int64
#
# -2    96771
#  0      286
#  1       10
# -1        3
# Name: acarbose, dtype: int64
#
# -2    97032
#  0       31
# -1        5
#  1        2
# Name: miglitol, dtype: int64
#
# -2    97067
#  0        3
# Name: troglitazone, dtype: int64
#
# -2    97031
#  0       38
#  1        1
# Name: tolazamide, dtype: int64
#
# -2    45487
#  0    29118
# -1    11735
#  1    10730
# Name: insulin, dtype: int64
#
# -2    96399
#  0      662
#  1        6
# -1        3
# Name: glyburide-metformin, dtype: int64
#
# -2    97057
#  0       13
# Name: glipizide-metformin, dtype: int64
#
# -2    97069
#  0        1
# Name: glimepiride-pioglitazone, dtype: int64
#
# -2    97070
# Name: metformin-rosiglitazone, dtype: int64
#
# -2    97069
#  0        1
# Name: metformin-pioglitazone, dtype: int64
#
# 0    52046
# 1    45024
# Name: change, dtype: int64
#
# 1    74842
# 0    22228
# Name: diabetesMed, dtype: int64
#
# insulin_only     29118
# other_meds       23259
# insulin_combo    22465
# no_med           22228
# Name: insulin_treatment, dtype: int64
