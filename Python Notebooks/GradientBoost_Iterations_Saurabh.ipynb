# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.metrics import classification_report, roc_auc_score, confusion_matrix
from sklearn.ensemble import GradientBoostingClassifier
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)
from imblearn.under_sampling import RandomUnderSampler, TomekLinks
from imblearn.over_sampling import SMOTE, SMOTENC, RandomOverSampler
from imblearn.combine import SMOTETomek
from scipy.stats import uniform, randint
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.neighbors.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neighbors. Anything that cannot be imported from sklearn.neighbors is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/My Drive/PGPDSE/Capstone/CSV Files/Diabetes_Preprocessed_Before_Feature_Selection.csv')
df.head()
# Out:
#               race  gender  age discharge_disposition_id admission_source_id  \
# 0        Caucasian       0    5            Not Available            Referral
# 1        Caucasian       0   15       Discharged to home           Emergency
# 2  AfricanAmerican       0   25       Discharged to home           Emergency
# 3        Caucasian       1   35       Discharged to home           Emergency
# 4        Caucasian       1   45       Discharged to home           Emergency
#
#    time_in_hospital  num_lab_procedures  num_procedures  num_medications  \
# 0                 1                  41               0                1
# 1                 3                  59               0               18
# 2                 2                  11               5               13
# 3                 2                  44               1               16
# 4                 1                  51               0                8
#
#                                         diag_1        diag_2  \
# 0                                     Diabetes  Not Required
# 1  Endocrine, Nutritional, Metabolic, Immunity      Diabetes
# 2                        Pregnancy, Childbirth      Diabetes
# 3                     Infectious and Parasitic      Diabetes
# 4                                    Neoplasms     Neoplasms
#
#                                         diag_3  number_diagnoses  \
# 0                                 Not Required                 1
# 1  Endocrine, Nutritional, Metabolic, Immunity                 9
# 2                    External causes of injury                 6
# 3                                  Circulatory                 7
# 4                                     Diabetes                 5
#
#   max_glu_serum A1Cresult  metformin  repaglinide  nateglinide  glimepiride  \
# 0          None      None         -2           -2           -2           -2
# 1          None      None         -2           -2           -2           -2
# 2          None      None         -2           -2           -2           -2
# 3          None      None         -2           -2           -2           -2
# 4          None      None         -2           -2           -2           -2
#
#    glipizide  glyburide  pioglitazone  rosiglitazone  insulin  \
# 0         -2         -2            -2             -2       -2
# 1         -2         -2            -2             -2        1
# 2          0         -2            -2             -2       -2
# 3         -2         -2            -2             -2        1
# 4          0         -2            -2             -2        0
#
#    glyburide-metformin  diabetesMed  readmitted  preceding_year_visits  \
# 0                   -2            0           0                      0
# 1                   -2            1           0                      0
# 2                   -2            1           0                      3
# 3                   -2            1           0                      0
# 4                   -2            1           0                      0
#
#    number_changes insulin_treatment
# 0               0            no_med
# 1               1      insulin_only
# 2               0        other_meds
# 3               1      insulin_only
# 4               0     insulin_combo

# %%
df.shape
# Out:
# (97070, 30)

# %%
X = df.drop('readmitted', 1)
y = df['readmitted']
X_dum = pd.get_dummies(X, drop_first = True)
X_train, X_test, y_train, y_test = train_test_split(X_dum, y, test_size = 0.3, random_state = 0, stratify = y)

# %%
model = GradientBoostingClassifier(random_state = 0)
model.fit(X_train, y_train)
sorted(zip(model.feature_importances_, X_train.columns), reverse = True)
# Out:
# [(0.4399437961887246, 'preceding_year_visits'),
#  (0.14916716517337786,
#   'discharge_disposition_id_Transferred to another medical facility'),
#  (0.03675321674542318, 'age'),
#  (0.03235826126558023, 'number_diagnoses'),
#  (0.028345531759157275, 'num_medications'),
#  (0.024792976799512024, 'time_in_hospital'),
#  (0.02413955481848056, 'insulin_treatment_insulin_only'),
#  (0.022673720381530982, 'diag_1_External causes of injury'),
#  (0.01781331252490117, 'num_lab_procedures'),
#  (0.017286799536575477,
#   'discharge_disposition_id_Still patient/referred to this institution'),
#  (0.012095674943428605, 'diag_2_Neoplasms'),
#  (0.011103871875848827, 'diag_3_Neoplasms'),
#  (0.010302500664576027, 'diag_2_Diabetes'),
#  (0.007182684718835615, 'diag_1_Respiratory'),
#  (0.007082551679241033, 'diag_1_Diabetes'),
#  (0.006951132874845997, 'diag_1_Musculoskeletal System and Connective Tissue'),
#  (0.006440853440397732, 'diag_1_Circulatory'),
#  (0.00626544984663948,
#   'discharge_disposition_id_Discharged to home with home health service'),
#  (0.006069397766642269,
#   'admission_source_id_Transferred from another health care facility'),
#  (0.005915698373007629, 'discharge_disposition_id_Left AMA'),
#  (0.005881615471250685, 'number_changes'),
#  (0.005850034068747974, 'diag_3_Diabetes'),
#  (0.005695830438435878, 'discharge_disposition_id_Not Available'),
#  (0.005385192250219743, 'metformin'),
#  (0.004827786659058219, 'admission_source_id_Referral'),
#  (0.004631028593403322, 'diabetesMed'),
#  (0.004586787518455064, 'A1Cresult_Norm'),
#  (0.0045536412578906565, 'diag_1_Mental Disorders'),
#  (0.004470174969789233, 'insulin'),
#  (0.004278730895657966, 'glipizide'),
#  (0.004263433142525422, 'num_procedures'),
#  (0.00417727141922344, 'repaglinide'),
#  (0.004131842288224529, 'admission_source_id_Not Available'),
#  (0.003952021065952229, 'max_glu_serum_>300'),
#  (0.0038134746902156245, 'A1Cresult_None'),
#  (0.0033310488255958743, 'diag_3_Nervous'),
#  (0.0027924913577953635, 'diag_3_Infectious and Parasitic'),
#  (0.002735569664990432, 'diag_3_Digestive'),
#  (0.0025531546454567334, 'diag_1_Pregnancy, Childbirth'),
#  (0.0025299156231256047, 'glyburide'),
#  (0.002449708363936422, 'glimepiride'),
#  (0.002216042400072343, 'diag_1_Sense Organs'),
#  (0.0022092615714040535, 'race_Caucasian'),
#  (0.002188697038158134, 'insulin_treatment_no_med'),
#  (0.0019673146558596994, 'max_glu_serum_None'),
#  (0.0018893280343437833, 'diag_2_Pregnancy, Childbirth'),
#  (0.0017101832033310216, 'diag_2_Nervous'),
#  (0.0017009411629436823, 'diag_2_External causes of injury'),
#  (0.0016682173155924353, 'diag_2_Endocrine, Nutritional, Metabolic, Immunity'),
#  (0.0016285721931513803, 'diag_3_Pregnancy, Childbirth'),
#  (0.0014870227593874136, 'diag_1_Skin and Subcutaneous Tissue'),
#  (0.0014685404370776121, 'race_Asian'),
#  (0.0014430280759205627, 'diag_3_Circulatory'),
#  (0.0013985754666984637, 'diag_3_External causes of injury'),
#  (0.0013788433219829514, 'diag_3_Genitourinary'),
#  (0.0013557792984846876, 'diag_2_Digestive'),
#  (0.0012590683008426309, 'max_glu_serum_Norm'),
#  (0.0011156685727975177, 'diag_3_Congenital Anomalies'),
#  (0.00108570821531035, 'diag_2_Respiratory'),
#  (0.0009667546302488745, 'diag_2_Not Required'),
#  (0.00094565076147005, 'rosiglitazone'),
#  (0.0009257385172272301, 'diag_2_Mental Disorders'),
#  (0.0007990500896455735, 'glyburide-metformin'),
#  (0.0007978624667504523, 'diag_3_Endocrine, Nutritional, Metabolic, Immunity'),
#  (0.0007086298749534169, 'diag_1_Congenital Anomalies'),
#  (0.0006684305445678318, 'gender'),
#  (0.000662646358707755, 'pioglitazone'),
#  (0.0006091051695882767, 'A1Cresult_>8'),
#  (0.0005931072321989084, 'diag_1_Endocrine, Nutritional, Metabolic, Immunity'),
#  (0.0005631107922372717, 'diag_1_Genitourinary'),
#  (0.0005389929141645158, 'diag_2_Other Symptoms'),
#  (0.0005251740626216079, 'diag_2_Skin and Subcutaneous Tissue'),
#  (0.0005086748530490042, 'diag_1_Injury and Poisoning'),
#  (0.0004939086890837587, 'diag_2_Circulatory'),
#  (0.0004421131314789675, 'diag_3_Respiratory'),
#  (0.00027732255448442857, 'diag_1_Other Symptoms'),
#  (0.0002280307474862911, 'diag_1_Neoplasms'),
#  (0.0, 'race_Other'),
#  (0.0, 'race_Hispanic'),
#  (0.0, 'nateglinide'),
#  (0.0, 'insulin_treatment_other_meds'),
#  (0.0, 'diag_3_Skin and Subcutaneous Tissue'),
#  (0.0, 'diag_3_Sense Organs'),
#  (0.0, 'diag_3_Other Symptoms'),
#  (0.0, 'diag_3_Not Required'),
#  (0.0, 'diag_3_Musculoskeletal System and Connective Tissue'),
#  (0.0, 'diag_3_Mental Disorders'),
#  (0.0, 'diag_3_Injury and Poisoning'),
#  (0.0, 'diag_2_Sense Organs'),
#  (0.0, 'diag_2_Musculoskeletal System and Connective Tissue'),
#  (0.0, 'diag_2_Injury and Poisoning'),
#  (0.0, 'diag_2_Infectious and Parasitic'),
#  (0.0, 'diag_2_Genitourinary'),
#  (0.0, 'diag_2_Congenital Anomalies'),
#  (0.0, 'diag_1_Nervous'),
#  (0.0, 'diag_1_Infectious and Parasitic'),
#  (0.0, 'diag_1_Digestive')]

# %%
fi_df = pd.DataFrame({'Features' : X_train.columns, 'Importances' : model.feature_importances_})
fi_df
# Out:
#                                              Features  Importances
# 0                                              gender     0.000668
# 1                                                 age     0.036753
# 2                                    time_in_hospital     0.024793
# 3                                  num_lab_procedures     0.017813
# 4                                      num_procedures     0.004263
# 5                                     num_medications     0.028346
# 6                                    number_diagnoses     0.032358
# 7                                           metformin     0.005385
# 8                                         repaglinide     0.004177
# 9                                         nateglinide     0.000000
# 10                                        glimepiride     0.002450
# 11                                          glipizide     0.004279
# 12                                          glyburide     0.002530
# 13                                       pioglitazone     0.000663
# 14                                      rosiglitazone     0.000946
# 15                                            insulin     0.004470
# 16                                glyburide-metformin     0.000799
# 17                                        diabetesMed     0.004631
# 18                              preceding_year_visits     0.439944
# 19                                     number_changes     0.005882
# 20                                         race_Asian     0.001469
# 21                                     race_Caucasian     0.002209
# 22                                      race_Hispanic     0.000000
# 23                                         race_Other     0.000000
# 24  discharge_disposition_id_Discharged to home wi...     0.006265
# 25                  discharge_disposition_id_Left AMA     0.005916
# 26             discharge_disposition_id_Not Available     0.005696
# 27  discharge_disposition_id_Still patient/referre...     0.017287
# 28  discharge_disposition_id_Transferred to anothe...     0.149167
# 29                  admission_source_id_Not Available     0.004132
# 30                       admission_source_id_Referral     0.004828
# 31  admission_source_id_Transferred from another h...     0.006069
# 32                                 diag_1_Circulatory     0.006441
# 33                        diag_1_Congenital Anomalies     0.000709
# 34                                    diag_1_Diabetes     0.007083
# 35                                   diag_1_Digestive     0.000000
# 36  diag_1_Endocrine, Nutritional, Metabolic, Immu...     0.000593
# 37                   diag_1_External causes of injury     0.022674
# 38                               diag_1_Genitourinary     0.000563
# 39                    diag_1_Infectious and Parasitic     0.000000
# 40                        diag_1_Injury and Poisoning     0.000509
# 41                            diag_1_Mental Disorders     0.004554
# 42  diag_1_Musculoskeletal System and Connective T...     0.006951
# 43                                   diag_1_Neoplasms     0.000228
# 44                                     diag_1_Nervous     0.000000
# 45                              diag_1_Other Symptoms     0.000277
# 46                       diag_1_Pregnancy, Childbirth     0.002553
# 47                                 diag_1_Respiratory     0.007183
# 48                                diag_1_Sense Organs     0.002216
# 49                diag_1_Skin and Subcutaneous Tissue     0.001487
# 50                                 diag_2_Circulatory     0.000494
# 51                        diag_2_Congenital Anomalies     0.000000
# 52                                    diag_2_Diabetes     0.010303
# 53                                   diag_2_Digestive     0.001356
# 54  diag_2_Endocrine, Nutritional, Metabolic, Immu...     0.001668
# 55                   diag_2_External causes of injury     0.001701
# 56                               diag_2_Genitourinary     0.000000
# 57                    diag_2_Infectious and Parasitic     0.000000
# 58                        diag_2_Injury and Poisoning     0.000000
# 59                            diag_2_Mental Disorders     0.000926
# 60  diag_2_Musculoskeletal System and Connective T...     0.000000
# 61                                   diag_2_Neoplasms     0.012096
# 62                                     diag_2_Nervous     0.001710
# 63                                diag_2_Not Required     0.000967
# 64                              diag_2_Other Symptoms     0.000539
# 65                       diag_2_Pregnancy, Childbirth     0.001889
# 66                                 diag_2_Respiratory     0.001086
# 67                                diag_2_Sense Organs     0.000000
# 68                diag_2_Skin and Subcutaneous Tissue     0.000525
# 69                                 diag_3_Circulatory     0.001443
# 70                        diag_3_Congenital Anomalies     0.001116
# 71                                    diag_3_Diabetes     0.005850
# 72                                   diag_3_Digestive     0.002736
# 73  diag_3_Endocrine, Nutritional, Metabolic, Immu...     0.000798
# 74                   diag_3_External causes of injury     0.001399
# 75                               diag_3_Genitourinary     0.001379
# 76                    diag_3_Infectious and Parasitic     0.002792
# 77                        diag_3_Injury and Poisoning     0.000000
# 78                            diag_3_Mental Disorders     0.000000
# 79  diag_3_Musculoskeletal System and Connective T...     0.000000
# 80                                   diag_3_Neoplasms     0.011104
# 81                                     diag_3_Nervous     0.003331
# 82                                diag_3_Not Required     0.000000
# 83                              diag_3_Other Symptoms     0.000000
# 84                       diag_3_Pregnancy, Childbirth     0.001629
# 85                                 diag_3_Respiratory     0.000442
# 86                                diag_3_Sense Organs     0.000000
# 87                diag_3_Skin and Subcutaneous Tissue     0.000000
# 88                                 max_glu_serum_>300     0.003952
# 89                                 max_glu_serum_None     0.001967
# 90                                 max_glu_serum_Norm     0.001259
# 91                                       A1Cresult_>8     0.000609
# 92                                     A1Cresult_None     0.003813
# 93                                     A1Cresult_Norm     0.004587
# 94                     insulin_treatment_insulin_only     0.024140
# 95                           insulin_treatment_no_med     0.002189
# 96                       insulin_treatment_other_meds     0.000000

# %%
imp = fi_df[fi_df['Importances'] >= 0]['Features']
print("Number of features:", len(imp))
model = GradientBoostingClassifier(random_state = 0)
model.fit(X_train[imp], y_train)
pred = model.predict(X_test[imp])
prob = model.predict_proba(X_test[imp])[:, 1]
print(confusion_matrix(y_test, pred))
print(classification_report(y_test, pred))
print("ROC_AUC:", roc_auc_score(y_test, prob))
# Out:
# Number of features: 97
# [[25775    10]
#  [ 3317    19]]
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94     25785
#            1       0.66      0.01      0.01      3336
#
#     accuracy                           0.89     29121
#    macro avg       0.77      0.50      0.48     29121
# weighted avg       0.86      0.89      0.83     29121
#
# ROC_AUC: 0.6631890357405757

# %%
imp = fi_df[fi_df['Importances'] >= 0.01]['Features']
print("Number of features:", len(imp))
model = GradientBoostingClassifier(random_state = 0)
model.fit(X_train[imp], y_train)
pred = model.predict(X_test[imp])
prob = model.predict_proba(X_test[imp])[:, 1]
print(confusion_matrix(y_test, pred))
print(classification_report(y_test, pred))
print("ROC_AUC:", roc_auc_score(y_test, prob))
# Out:
# Number of features: 13
# [[25775    10]
#  [ 3318    18]]
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94     25785
#            1       0.64      0.01      0.01      3336
#
#     accuracy                           0.89     29121
#    macro avg       0.76      0.50      0.48     29121
# weighted avg       0.86      0.89      0.83     29121
#
# ROC_AUC: 0.6562559144075083

# %% [markdown]
# ### Sampling Techniques

# %% [markdown]
# #### Under Sampling

# %%
rus = RandomUnderSampler(random_state = 0)
X_rus, y_rus = rus.fit_resample(X_train[imp], y_train)
model = GradientBoostingClassifier(random_state = 0)
model.fit(X_rus, y_rus)
pred = model.predict(X_test[imp])
prob = model.predict_proba(X_test[imp])[:, 1]
print(confusion_matrix(y_test, pred))
print(classification_report(y_test, pred))
print("ROC_AUC:", roc_auc_score(y_test, prob))
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# [[15700 10085]
#  [ 1277  2059]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.61      0.73     25785
#            1       0.17      0.62      0.27      3336
#
#     accuracy                           0.61     29121
#    macro avg       0.55      0.61      0.50     29121
# weighted avg       0.84      0.61      0.68     29121
#
# ROC_AUC: 0.6539001085344638

# %% [markdown]
# #### Over Sampling

# %%
ros = RandomOverSampler(random_state = 0)
X_ros, y_ros = ros.fit_resample(X_train[imp], y_train)
model = GradientBoostingClassifier(random_state = 0)
model.fit(X_ros, y_ros)
pred = model.predict(X_test[imp])
prob = model.predict_proba(X_test[imp])[:, 1]
print(confusion_matrix(y_test, pred))
print(classification_report(y_test, pred))
print("ROC_AUC:", roc_auc_score(y_test, prob))
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# [[15816  9969]
#  [ 1303  2033]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.61      0.74     25785
#            1       0.17      0.61      0.27      3336
#
#     accuracy                           0.61     29121
#    macro avg       0.55      0.61      0.50     29121
# weighted avg       0.84      0.61      0.68     29121
#
# ROC_AUC: 0.6547157038766892

# %% [markdown]
# #### SMOTE

# %%
sm = SMOTE(random_state = 0, n_jobs = -1)
X_sm, y_sm = sm.fit_resample(X_train[imp], y_train)
model = GradientBoostingClassifier(random_state = 0)
model.fit(X_sm, y_sm)
pred = model.predict(X_test[imp])
prob = model.predict_proba(X_test[imp])[:, 1]
print(confusion_matrix(y_test, pred))
print(classification_report(y_test, pred))
print("ROC_AUC:", roc_auc_score(y_test, prob))
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# [[13928 11857]
#  [ 1754  1582]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.54      0.67     25785
#            1       0.12      0.47      0.19      3336
#
#     accuracy                           0.53     29121
#    macro avg       0.50      0.51      0.43     29121
# weighted avg       0.80      0.53      0.62     29121
#
# ROC_AUC: 0.5256856701956643

# %% [markdown]
# #### SmoteTomek

# %%
smtmk = SMOTETomek(random_state = 0)
X_smtmk, y_smtmk = sm.fit_resample(X_train[imp], y_train)
model = GradientBoostingClassifier(random_state = 0)
model.fit(X_smtmk, y_smtmk)
pred = model.predict(X_test[imp])
prob = model.predict_proba(X_test[imp])[:, 1]
print(confusion_matrix(y_test, pred))
print(classification_report(y_test, pred))
print("ROC_AUC:", roc_auc_score(y_test, prob))
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# [[13928 11857]
#  [ 1754  1582]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.54      0.67     25785
#            1       0.12      0.47      0.19      3336
#
#     accuracy                           0.53     29121
#    macro avg       0.50      0.51      0.43     29121
# weighted avg       0.80      0.53      0.62     29121
#
# ROC_AUC: 0.5256856701956643

# %% [markdown]
# ### Hyper-Parameter Tuning

# %%
X_rus.shape, X_ros.shape
# Out:
# ((15568, 13), (120330, 13))

# %%
np.logspace(-2, 0, 100)
# Out:
# array([0.01      , 0.01047616, 0.01097499, 0.01149757, 0.01204504,
#        0.01261857, 0.01321941, 0.01384886, 0.01450829, 0.01519911,
#        0.01592283, 0.01668101, 0.01747528, 0.01830738, 0.0191791 ,
#        0.02009233, 0.02104904, 0.02205131, 0.0231013 , 0.02420128,
#        0.02535364, 0.02656088, 0.02782559, 0.02915053, 0.03053856,
#        0.03199267, 0.03351603, 0.03511192, 0.0367838 , 0.03853529,
#        0.04037017, 0.04229243, 0.04430621, 0.04641589, 0.04862602,
#        0.05094138, 0.05336699, 0.0559081 , 0.05857021, 0.06135907,
#        0.06428073, 0.06734151, 0.07054802, 0.07390722, 0.07742637,
#        0.08111308, 0.08497534, 0.08902151, 0.09326033, 0.097701  ,
#        0.1023531 , 0.10722672, 0.1123324 , 0.1176812 , 0.12328467,
#        0.12915497, 0.13530478, 0.14174742, 0.14849683, 0.15556761,
#        0.16297508, 0.17073526, 0.17886495, 0.18738174, 0.19630407,
#        0.20565123, 0.21544347, 0.22570197, 0.23644894, 0.24770764,
#        0.25950242, 0.27185882, 0.28480359, 0.29836472, 0.31257158,
#        0.32745492, 0.34304693, 0.35938137, 0.37649358, 0.39442061,
#        0.41320124, 0.43287613, 0.45348785, 0.47508102, 0.49770236,
#        0.52140083, 0.54622772, 0.57223677, 0.59948425, 0.62802914,
#        0.65793322, 0.68926121, 0.7220809 , 0.75646333, 0.7924829 ,
#        0.83021757, 0.869749  , 0.91116276, 0.95454846, 1.        ])

# %%
model = GradientBoostingClassifier(random_state = 0)

params = {'n_estimators' : np.arange(100, 500),
          'learning_rate' : np.logspace(-2, 0, 100),
          'min_samples_split' : np.arange(2, 50),
          'min_samples_leaf' : np.arange(1, 50),
          'max_depth' : np.arange(3, 30),
          'max_features' : np.arange(1, 13),}

rsearch = RandomizedSearchCV(model, params, n_iter = 10, scoring = 'recall', n_jobs = -1,
                             cv = 5, verbose = 1, random_state = 0)
rsearch.fit(X_rus, y_rus)
rsearch.best_score_, rsearch.best_params_
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed:  6.3min
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:  7.5min finished
# (0.5874881330354829,
#  {'learning_rate': 0.011497569953977356,
#   'max_depth': 25,
#   'max_features': 9,
#   'min_samples_leaf': 37,
#   'min_samples_split': 10,
#   'n_estimators': 368})

# %%
model = GradientBoostingClassifier(random_state = 0)

params = {'n_estimators' : np.arange(300, 500),
          'learning_rate' : np.logspace(-3, -1, 100),
          'min_samples_split' : np.arange(5, 15),
          'min_samples_leaf' : np.arange(30, 60),
          'max_depth' : np.arange(20, 40),
          'max_features' : np.arange(1, 13),}

rsearch = RandomizedSearchCV(model, params, n_iter = 10, scoring = 'recall', n_jobs = -1,
                             cv = 5, verbose = 1, random_state = 0)
rsearch.fit(X_ros, y_ros)
rsearch.best_score_, rsearch.best_params_
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed: 103.7min
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed: 110.4min finished
# (0.9988199119089172,
#  {'learning_rate': 0.05994842503189412,
#   'max_depth': 34,
#   'max_features': 11,
#   'min_samples_leaf': 40,
#   'min_samples_split': 11,
#   'n_estimators': 499})

# %%
model = rsearch.best_estimator_
model.fit(X_ros, y_ros)
pred = model.predict(X_test[imp])
prob = model.predict_proba(X_test[imp])[:, 1]
print(confusion_matrix(y_test, pred))
print(classification_report(y_test, pred))
print("ROC_AUC:", roc_auc_score(y_test, prob))
# Out:
# [[24168  1617]
#  [ 2995   341]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.94      0.91     25785
#            1       0.17      0.10      0.13      3336
#
#     accuracy                           0.84     29121
#    macro avg       0.53      0.52      0.52     29121
# weighted avg       0.81      0.84      0.82     29121
#
# ROC_AUC: 0.5750269185466054
