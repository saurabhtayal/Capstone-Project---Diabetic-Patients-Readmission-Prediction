# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.metrics import classification_report, roc_auc_score, confusion_matrix
from sklearn.ensemble import AdaBoostClassifier
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)
from imblearn.under_sampling import RandomUnderSampler, TomekLinks
from imblearn.over_sampling import SMOTE, SMOTENC, RandomOverSampler
from imblearn.combine import SMOTETomek
from scipy.stats import uniform, randint

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/My Drive/PGPDSE/Capstone/CSV Files/Diabetes_Preprocessed_Before_Feature_Selection.csv')
df.head()
# Out:
#               race  gender  age discharge_disposition_id admission_source_id  \
# 0        Caucasian       0    5            Not Available            Referral
# 1        Caucasian       0   15       Discharged to home           Emergency
# 2  AfricanAmerican       0   25       Discharged to home           Emergency
# 3        Caucasian       1   35       Discharged to home           Emergency
# 4        Caucasian       1   45       Discharged to home           Emergency
#
#    time_in_hospital  num_lab_procedures  num_procedures  num_medications  \
# 0                 1                  41               0                1
# 1                 3                  59               0               18
# 2                 2                  11               5               13
# 3                 2                  44               1               16
# 4                 1                  51               0                8
#
#                                         diag_1        diag_2  \
# 0                                     Diabetes  Not Required
# 1  Endocrine, Nutritional, Metabolic, Immunity      Diabetes
# 2                        Pregnancy, Childbirth      Diabetes
# 3                     Infectious and Parasitic      Diabetes
# 4                                    Neoplasms     Neoplasms
#
#                                         diag_3  number_diagnoses  \
# 0                                 Not Required                 1
# 1  Endocrine, Nutritional, Metabolic, Immunity                 9
# 2                    External causes of injury                 6
# 3                                  Circulatory                 7
# 4                                     Diabetes                 5
#
#   max_glu_serum A1Cresult  metformin  repaglinide  nateglinide  glimepiride  \
# 0          None      None         -2           -2           -2           -2
# 1          None      None         -2           -2           -2           -2
# 2          None      None         -2           -2           -2           -2
# 3          None      None         -2           -2           -2           -2
# 4          None      None         -2           -2           -2           -2
#
#    glipizide  glyburide  pioglitazone  rosiglitazone  insulin  \
# 0         -2         -2            -2             -2       -2
# 1         -2         -2            -2             -2        1
# 2          0         -2            -2             -2       -2
# 3         -2         -2            -2             -2        1
# 4          0         -2            -2             -2        0
#
#    glyburide-metformin  diabetesMed  readmitted  preceding_year_visits  \
# 0                   -2            0           0                      0
# 1                   -2            1           0                      0
# 2                   -2            1           0                      3
# 3                   -2            1           0                      0
# 4                   -2            1           0                      0
#
#    number_changes insulin_treatment
# 0               0            no_med
# 1               1      insulin_only
# 2               0        other_meds
# 3               1      insulin_only
# 4               0     insulin_combo

# %%
df.shape
# Out:
# (97070, 30)

# %%
X = df.drop('readmitted', 1)
y = df['readmitted']
X_dum = pd.get_dummies(X, drop_first = True)
X_train, X_test, y_train, y_test = train_test_split(X_dum, y, test_size = 0.3, random_state = 0, stratify = y)

# %%
model = AdaBoostClassifier(random_state = 0)
model.fit(X_train, y_train)
sorted(zip(model.feature_importances_, X_train.columns), reverse = True)
# Out:
# [(0.16, 'preceding_year_visits'),
#  (0.08, 'time_in_hospital'),
#  (0.08, 'age'),
#  (0.06, 'num_medications'),
#  (0.02, 'number_diagnoses'),
#  (0.02, 'num_procedures'),
#  (0.02, 'num_lab_procedures'),
#  (0.02, 'metformin'),
#  (0.02, 'insulin_treatment_insulin_only'),
#  (0.02, 'insulin'),
#  (0.02, 'gender'),
#  (0.02, 'discharge_disposition_id_Transferred to another medical facility'),
#  (0.02, 'discharge_disposition_id_Still patient/referred to this institution'),
#  (0.02, 'discharge_disposition_id_Not Available'),
#  (0.02, 'discharge_disposition_id_Left AMA'),
#  (0.02,
#   'discharge_disposition_id_Discharged to home with home health service'),
#  (0.02, 'diag_3_Pregnancy, Childbirth'),
#  (0.02, 'diag_3_Neoplasms'),
#  (0.02, 'diag_3_External causes of injury'),
#  (0.02, 'diag_3_Endocrine, Nutritional, Metabolic, Immunity'),
#  (0.02, 'diag_3_Circulatory'),
#  (0.02, 'diag_2_Pregnancy, Childbirth'),
#  (0.02, 'diag_2_Neoplasms'),
#  (0.02, 'diag_2_Diabetes'),
#  (0.02, 'diag_1_Sense Organs'),
#  (0.02, 'diag_1_Respiratory'),
#  (0.02, 'diag_1_Other Symptoms'),
#  (0.02, 'diag_1_Musculoskeletal System and Connective Tissue'),
#  (0.02, 'diag_1_External causes of injury'),
#  (0.02, 'diag_1_Diabetes'),
#  (0.02, 'diag_1_Circulatory'),
#  (0.02, 'diabetesMed'),
#  (0.02, 'admission_source_id_Transferred from another health care facility'),
#  (0.02, 'admission_source_id_Not Available'),
#  (0.02, 'A1Cresult_None'),
#  (0.0, 'rosiglitazone'),
#  (0.0, 'repaglinide'),
#  (0.0, 'race_Other'),
#  (0.0, 'race_Hispanic'),
#  (0.0, 'race_Caucasian'),
#  (0.0, 'race_Asian'),
#  (0.0, 'pioglitazone'),
#  (0.0, 'number_changes'),
#  (0.0, 'nateglinide'),
#  (0.0, 'max_glu_serum_Norm'),
#  (0.0, 'max_glu_serum_None'),
#  (0.0, 'max_glu_serum_>300'),
#  (0.0, 'insulin_treatment_other_meds'),
#  (0.0, 'insulin_treatment_no_med'),
#  (0.0, 'glyburide-metformin'),
#  (0.0, 'glyburide'),
#  (0.0, 'glipizide'),
#  (0.0, 'glimepiride'),
#  (0.0, 'diag_3_Skin and Subcutaneous Tissue'),
#  (0.0, 'diag_3_Sense Organs'),
#  (0.0, 'diag_3_Respiratory'),
#  (0.0, 'diag_3_Other Symptoms'),
#  (0.0, 'diag_3_Not Required'),
#  (0.0, 'diag_3_Nervous'),
#  (0.0, 'diag_3_Musculoskeletal System and Connective Tissue'),
#  (0.0, 'diag_3_Mental Disorders'),
#  (0.0, 'diag_3_Injury and Poisoning'),
#  (0.0, 'diag_3_Infectious and Parasitic'),
#  (0.0, 'diag_3_Genitourinary'),
#  (0.0, 'diag_3_Digestive'),
#  (0.0, 'diag_3_Diabetes'),
#  (0.0, 'diag_3_Congenital Anomalies'),
#  (0.0, 'diag_2_Skin and Subcutaneous Tissue'),
#  (0.0, 'diag_2_Sense Organs'),
#  (0.0, 'diag_2_Respiratory'),
#  (0.0, 'diag_2_Other Symptoms'),
#  (0.0, 'diag_2_Not Required'),
#  (0.0, 'diag_2_Nervous'),
#  (0.0, 'diag_2_Musculoskeletal System and Connective Tissue'),
#  (0.0, 'diag_2_Mental Disorders'),
#  (0.0, 'diag_2_Injury and Poisoning'),
#  (0.0, 'diag_2_Infectious and Parasitic'),
#  (0.0, 'diag_2_Genitourinary'),
#  (0.0, 'diag_2_External causes of injury'),
#  (0.0, 'diag_2_Endocrine, Nutritional, Metabolic, Immunity'),
#  (0.0, 'diag_2_Digestive'),
#  (0.0, 'diag_2_Congenital Anomalies'),
#  (0.0, 'diag_2_Circulatory'),
#  (0.0, 'diag_1_Skin and Subcutaneous Tissue'),
#  (0.0, 'diag_1_Pregnancy, Childbirth'),
#  (0.0, 'diag_1_Nervous'),
#  (0.0, 'diag_1_Neoplasms'),
#  (0.0, 'diag_1_Mental Disorders'),
#  (0.0, 'diag_1_Injury and Poisoning'),
#  (0.0, 'diag_1_Infectious and Parasitic'),
#  (0.0, 'diag_1_Genitourinary'),
#  (0.0, 'diag_1_Endocrine, Nutritional, Metabolic, Immunity'),
#  (0.0, 'diag_1_Digestive'),
#  (0.0, 'diag_1_Congenital Anomalies'),
#  (0.0, 'admission_source_id_Referral'),
#  (0.0, 'A1Cresult_Norm'),
#  (0.0, 'A1Cresult_>8')]

# %%
fi_df = pd.DataFrame({'Features' : X_train.columns, 'Importances' : model.feature_importances_})
fi_df
# Out:
#                                              Features  Importances
# 0                                              gender         0.02
# 1                                                 age         0.08
# 2                                    time_in_hospital         0.08
# 3                                  num_lab_procedures         0.02
# 4                                      num_procedures         0.02
# 5                                     num_medications         0.06
# 6                                    number_diagnoses         0.02
# 7                                           metformin         0.02
# 8                                         repaglinide         0.00
# 9                                         nateglinide         0.00
# 10                                        glimepiride         0.00
# 11                                          glipizide         0.00
# 12                                          glyburide         0.00
# 13                                       pioglitazone         0.00
# 14                                      rosiglitazone         0.00
# 15                                            insulin         0.02
# 16                                glyburide-metformin         0.00
# 17                                        diabetesMed         0.02
# 18                              preceding_year_visits         0.16
# 19                                     number_changes         0.00
# 20                                         race_Asian         0.00
# 21                                     race_Caucasian         0.00
# 22                                      race_Hispanic         0.00
# 23                                         race_Other         0.00
# 24  discharge_disposition_id_Discharged to home wi...         0.02
# 25                  discharge_disposition_id_Left AMA         0.02
# 26             discharge_disposition_id_Not Available         0.02
# 27  discharge_disposition_id_Still patient/referre...         0.02
# 28  discharge_disposition_id_Transferred to anothe...         0.02
# 29                  admission_source_id_Not Available         0.02
# 30                       admission_source_id_Referral         0.00
# 31  admission_source_id_Transferred from another h...         0.02
# 32                                 diag_1_Circulatory         0.02
# 33                        diag_1_Congenital Anomalies         0.00
# 34                                    diag_1_Diabetes         0.02
# 35                                   diag_1_Digestive         0.00
# 36  diag_1_Endocrine, Nutritional, Metabolic, Immu...         0.00
# 37                   diag_1_External causes of injury         0.02
# 38                               diag_1_Genitourinary         0.00
# 39                    diag_1_Infectious and Parasitic         0.00
# 40                        diag_1_Injury and Poisoning         0.00
# 41                            diag_1_Mental Disorders         0.00
# 42  diag_1_Musculoskeletal System and Connective T...         0.02
# 43                                   diag_1_Neoplasms         0.00
# 44                                     diag_1_Nervous         0.00
# 45                              diag_1_Other Symptoms         0.02
# 46                       diag_1_Pregnancy, Childbirth         0.00
# 47                                 diag_1_Respiratory         0.02
# 48                                diag_1_Sense Organs         0.02
# 49                diag_1_Skin and Subcutaneous Tissue         0.00
# 50                                 diag_2_Circulatory         0.00
# 51                        diag_2_Congenital Anomalies         0.00
# 52                                    diag_2_Diabetes         0.02
# 53                                   diag_2_Digestive         0.00
# 54  diag_2_Endocrine, Nutritional, Metabolic, Immu...         0.00
# 55                   diag_2_External causes of injury         0.00
# 56                               diag_2_Genitourinary         0.00
# 57                    diag_2_Infectious and Parasitic         0.00
# 58                        diag_2_Injury and Poisoning         0.00
# 59                            diag_2_Mental Disorders         0.00
# 60  diag_2_Musculoskeletal System and Connective T...         0.00
# 61                                   diag_2_Neoplasms         0.02
# 62                                     diag_2_Nervous         0.00
# 63                                diag_2_Not Required         0.00
# 64                              diag_2_Other Symptoms         0.00
# 65                       diag_2_Pregnancy, Childbirth         0.02
# 66                                 diag_2_Respiratory         0.00
# 67                                diag_2_Sense Organs         0.00
# 68                diag_2_Skin and Subcutaneous Tissue         0.00
# 69                                 diag_3_Circulatory         0.02
# 70                        diag_3_Congenital Anomalies         0.00
# 71                                    diag_3_Diabetes         0.00
# 72                                   diag_3_Digestive         0.00
# 73  diag_3_Endocrine, Nutritional, Metabolic, Immu...         0.02
# 74                   diag_3_External causes of injury         0.02
# 75                               diag_3_Genitourinary         0.00
# 76                    diag_3_Infectious and Parasitic         0.00
# 77                        diag_3_Injury and Poisoning         0.00
# 78                            diag_3_Mental Disorders         0.00
# 79  diag_3_Musculoskeletal System and Connective T...         0.00
# 80                                   diag_3_Neoplasms         0.02
# 81                                     diag_3_Nervous         0.00
# 82                                diag_3_Not Required         0.00
# 83                              diag_3_Other Symptoms         0.00
# 84                       diag_3_Pregnancy, Childbirth         0.02
# 85                                 diag_3_Respiratory         0.00
# 86                                diag_3_Sense Organs         0.00
# 87                diag_3_Skin and Subcutaneous Tissue         0.00
# 88                                 max_glu_serum_>300         0.00
# 89                                 max_glu_serum_None         0.00
# 90                                 max_glu_serum_Norm         0.00
# 91                                       A1Cresult_>8         0.00
# 92                                     A1Cresult_None         0.02
# 93                                     A1Cresult_Norm         0.00
# 94                     insulin_treatment_insulin_only         0.02
# 95                           insulin_treatment_no_med         0.00
# 96                       insulin_treatment_other_meds         0.00

# %%
imp = fi_df[fi_df['Importances'] >= 0]['Features']
print("Number of features:", len(imp))
model = AdaBoostClassifier(random_state = 0)
model.fit(X_train[imp], y_train)
pred = model.predict(X_test[imp])
prob = model.predict_proba(X_test[imp])[:, 1]
print(confusion_matrix(y_test, pred))
print(classification_report(y_test, pred))
print("ROC_AUC:", roc_auc_score(y_test, prob))
# Out:
# Number of features: 97
# [[25783     2]
#  [ 3334     2]]
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94     25785
#            1       0.50      0.00      0.00      3336
#
#     accuracy                           0.89     29121
#    macro avg       0.69      0.50      0.47     29121
# weighted avg       0.84      0.89      0.83     29121
#
# ROC_AUC: 0.6560870849568164

# %%
imp = fi_df[fi_df['Importances'] > 0]['Features']
print("Number of features:", len(imp))
model = AdaBoostClassifier(random_state = 0)
model.fit(X_train[imp], y_train)
pred = model.predict(X_test[imp])
prob = model.predict_proba(X_test[imp])[:, 1]
print(confusion_matrix(y_test, pred))
print(classification_report(y_test, pred))
print("ROC_AUC:", roc_auc_score(y_test, prob))
# Out:
# Number of features: 35
# [[25783     2]
#  [ 3334     2]]
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94     25785
#            1       0.50      0.00      0.00      3336
#
#     accuracy                           0.89     29121
#    macro avg       0.69      0.50      0.47     29121
# weighted avg       0.84      0.89      0.83     29121
#
# ROC_AUC: 0.6560870849568164

# %% [markdown]
# ### Sampling Techniques

# %% [markdown]
# #### Under Sampling

# %%
rus = RandomUnderSampler(random_state = 0)
X_rus, y_rus = rus.fit_resample(X_train[imp], y_train)
model = AdaBoostClassifier(random_state = 0)
model.fit(X_rus, y_rus)
pred = model.predict(X_test[imp])
prob = model.predict_proba(X_test[imp])[:, 1]
print(confusion_matrix(y_test, pred))
print(classification_report(y_test, pred))
print("ROC_AUC:", roc_auc_score(y_test, prob))
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# [[16566  9219]
#  [ 1406  1930]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.64      0.76     25785
#            1       0.17      0.58      0.27      3336
#
#     accuracy                           0.64     29121
#    macro avg       0.55      0.61      0.51     29121
# weighted avg       0.84      0.64      0.70     29121
#
# ROC_AUC: 0.6531558406561545

# %% [markdown]
# #### Over Sampling

# %%
ros = RandomOverSampler(random_state = 0)
X_ros, y_ros = ros.fit_resample(X_train[imp], y_train)
model = AdaBoostClassifier(random_state = 0)
model.fit(X_ros, y_ros)
pred = model.predict(X_test[imp])
prob = model.predict_proba(X_test[imp])[:, 1]
print(confusion_matrix(y_test, pred))
print(classification_report(y_test, pred))
print("ROC_AUC:", roc_auc_score(y_test, prob))
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# [[16488  9297]
#  [ 1390  1946]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.64      0.76     25785
#            1       0.17      0.58      0.27      3336
#
#     accuracy                           0.63     29121
#    macro avg       0.55      0.61      0.51     29121
# weighted avg       0.84      0.63      0.70     29121
#
# ROC_AUC: 0.6563384022276071

# %% [markdown]
# #### SMOTE

# %%
sm = SMOTE(random_state = 0, n_jobs = -1)
X_sm, y_sm = sm.fit_resample(X_train[imp], y_train)
model = AdaBoostClassifier(random_state = 0)
model.fit(X_sm, y_sm)
pred = model.predict(X_test[imp])
prob = model.predict_proba(X_test[imp])[:, 1]
print(confusion_matrix(y_test, pred))
print(classification_report(y_test, pred))
print("ROC_AUC:", roc_auc_score(y_test, prob))
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# [[19730  6055]
#  [ 2506   830]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.77      0.82     25785
#            1       0.12      0.25      0.16      3336
#
#     accuracy                           0.71     29121
#    macro avg       0.50      0.51      0.49     29121
# weighted avg       0.80      0.71      0.75     29121
#
# ROC_AUC: 0.5220423893578564

# %% [markdown]
# #### SmoteTomek

# %%
smtmk = SMOTETomek(random_state = 0)
X_smtmk, y_smtmk = sm.fit_resample(X_train[imp], y_train)
model = AdaBoostClassifier(random_state = 0)
model.fit(X_smtmk, y_smtmk)
pred = model.predict(X_test[imp])
prob = model.predict_proba(X_test[imp])[:, 1]
print(confusion_matrix(y_test, pred))
print(classification_report(y_test, pred))
print("ROC_AUC:", roc_auc_score(y_test, prob))
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# [[19730  6055]
#  [ 2506   830]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.77      0.82     25785
#            1       0.12      0.25      0.16      3336
#
#     accuracy                           0.71     29121
#    macro avg       0.50      0.51      0.49     29121
# weighted avg       0.80      0.71      0.75     29121
#
# ROC_AUC: 0.5220423893578564

# %% [markdown]
# ### Hyper-Parameter Tuning

# %%
X_rus.shape, X_ros.shape
# Out:
# ((15568, 35), (120330, 35))

# %%
np.logspace(-1, 1, 100)
# Out:
# array([ 0.1       ,  0.10476158,  0.10974988,  0.1149757 ,  0.12045035,
#         0.12618569,  0.13219411,  0.13848864,  0.14508288,  0.15199111,
#         0.15922828,  0.16681005,  0.17475284,  0.18307383,  0.19179103,
#         0.2009233 ,  0.21049041,  0.22051307,  0.23101297,  0.24201283,
#         0.25353645,  0.26560878,  0.27825594,  0.29150531,  0.30538555,
#         0.31992671,  0.33516027,  0.35111917,  0.36783798,  0.38535286,
#         0.40370173,  0.42292429,  0.44306215,  0.46415888,  0.48626016,
#         0.5094138 ,  0.53366992,  0.55908102,  0.58570208,  0.61359073,
#         0.64280731,  0.67341507,  0.70548023,  0.7390722 ,  0.77426368,
#         0.81113083,  0.84975344,  0.89021509,  0.93260335,  0.97700996,
#         1.02353102,  1.07226722,  1.12332403,  1.17681195,  1.23284674,
#         1.29154967,  1.35304777,  1.41747416,  1.48496826,  1.55567614,
#         1.62975083,  1.70735265,  1.78864953,  1.87381742,  1.96304065,
#         2.05651231,  2.15443469,  2.25701972,  2.36448941,  2.47707636,
#         2.59502421,  2.71858824,  2.84803587,  2.98364724,  3.12571585,
#         3.27454916,  3.43046929,  3.59381366,  3.76493581,  3.94420606,
#         4.1320124 ,  4.32876128,  4.53487851,  4.75081016,  4.97702356,
#         5.21400829,  5.46227722,  5.72236766,  5.9948425 ,  6.28029144,
#         6.57933225,  6.8926121 ,  7.22080902,  7.56463328,  7.92482898,
#         8.30217568,  8.69749003,  9.11162756,  9.54548457, 10.        ])

# %%
model = AdaBoostClassifier(random_state = 0)
params = {'n_estimators' : np.arange(100, 1000),
          'learning_rate' : np.logspace(-1, 1, 100)}
rsearch = RandomizedSearchCV(model, params, n_iter = 50, scoring = 'recall', n_jobs = -1,
                             cv = 5, verbose = 1, random_state = 0)
rsearch.fit(X_ros, y_ros)
rsearch.best_score_, rsearch.best_params_
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed: 31.0min
# [Parallel(n_jobs=-1)]: Done 196 tasks      | elapsed: 122.8min
# [Parallel(n_jobs=-1)]: Done 250 out of 250 | elapsed: 163.3min finished

# %%
model = AdaBoostClassifier(random_state = 0)
params = {'n_estimators' : np.arange(100, 1000),
          'learning_rate' : np.logspace(-1, 1, 100)}
rsearch = RandomizedSearchCV(model, params, n_iter = 50, scoring = 'recall', n_jobs = -1,
                             cv = 5, verbose = 1, random_state = 0)
rsearch.fit(X_rus, y_rus)
rsearch.best_score_, rsearch.best_params_
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed:  3.8min
# [Parallel(n_jobs=-1)]: Done 196 tasks      | elapsed: 14.5min
# [Parallel(n_jobs=-1)]: Done 250 out of 250 | elapsed: 18.9min finished
# (1.0, {'learning_rate': 6.280291441834256, 'n_estimators': 471})

# %%
rsearch.best_score_
# Out:
# 1.0

# %%
model = rsearch.best_estimator_
model.fit(X_rus, y_rus)
pred = model.predict(X_test[imp])
prob = model.predict_proba(X_test[imp])[:, 1]
print(confusion_matrix(y_test, pred))
print(classification_report(y_test, pred))
print("ROC_AUC:", roc_auc_score(y_test, prob))
# Out:
# [[    0 25785]
#  [    0  3336]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00     25785
#            1       0.11      1.00      0.21      3336
#
#     accuracy                           0.11     29121
#    macro avg       0.06      0.50      0.10     29121
# weighted avg       0.01      0.11      0.02     29121
#
# ROC_AUC: 0.5819535471099561
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
